# %% [markdown]
# <b><h4> Multi-Layer perceptron</h4></b>

# %% [markdown]
# # Import & Helper Functions

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

import gdown
from sklearn.datasets import fetch_openml
from tensorflow.keras.utils import to_categorical
from sklearn.model_selection import train_test_split
import time
import random

import torch
import torch.nn as nn
import torch.optim as optim

from torchvision import transforms
from torchvision.utils import make_grid
from torchvision.datasets import ImageFolder
from torch.utils.data import DataLoader, TensorDataset

from tqdm.auto import tqdm
from IPython.display import display

# %%
def seed_setter(seed=None, seed_torch=True):
  """
  Function that controls randomness.

  Args:
    seed : Integer
      A non-negative integer that defines the random state.
    seed_torch : Boolean
      If `True` sets the random seed for pytorch tensors.

  Returns:
    Nothing.
  """
  if seed is None:
    seed = np.random.choice(2 ** 32)
  random.seed(seed)
  np.random.seed(seed)
  if seed_torch:
    torch.manual_seed(seed)
    torch.cuda.manual_seed_all(seed)
    torch.cuda.manual_seed(seed)
    torch.backends.cudnn.benchmark = False
    torch.backends.cudnn.deterministic = True

  print(f'Random seed {seed} has been set.')


# In case that `DataLoader` is used
def seed_worker(worker_id):

  worker_seed = torch.initial_seed() % 2**32
  np.random.seed(worker_seed)
  random.seed(worker_seed)


def train_test_classification(net, criterion, optimizer, train_loader,
                              test_loader, num_epochs=1, verbose=True,
                              training_plot=False):
  """
  Accumulate training loss/Evaluate performance

  Args:
    net: Instance of Net class
      Describes the model with ReLU activation, batch size 128
    criterion: torch.nn type
      Criterion combines LogSoftmax and NLLLoss in one single class.
    optimizer: torch.optim type
      Implements Adam algorithm.
    train_loader: torch.utils.data type
      Combines the train dataset and sampler, and provides an iterable over the given dataset.
    test_loader: torch.utils.data type
      Combines the test dataset and sampler, and provides an iterable over the given dataset.
    num_epochs: int
      Number of epochs [default: 1]
    verbose: boolean
      If True, print statistics
    training_plot=False
      If True, display training plot

  Returns:
    Nothing
  """
  net.train()
  train_losses = []
  for epoch in tqdm(range(num_epochs)):
    running_loss = 0.0
    for i, data in enumerate(train_loader, 0):
      # Get the inputs; data is a list of [inputs, labels]
      inputs, labels = data
      inputs = inputs.float()
      labels = labels.long()

      optimizer.zero_grad()
      outputs = net(inputs)

      loss = criterion(outputs, labels)
      loss.backward()
      optimizer.step()

      if verbose:
        train_losses += [loss.item()]

  net.eval()

  def test(data_loader):
    """
    Function to gauge network performance

    Args:
      data_loader: torch.utils.data type
        Combines the test dataset and sampler, and provides an iterable over the given dataset.

    Returns:
      acc: float
        Performance of the network
      total: int
        Number of datapoints in the dataloader
    """
    correct = 0
    total = 0
    for data in data_loader:
      inputs, labels = data
      inputs = inputs.float()
      labels = labels.long()

      outputs = net(inputs)
      _, predicted = torch.max(outputs, 1)
      total += labels.size(0)
      correct += (predicted == labels).sum().item()

    acc = 100 * correct / total
    return total, acc

  train_total, train_acc = test(train_loader)
  test_total, test_acc = test(test_loader)

  if verbose:
    print(f'\nAccuracy on the {train_total} training samples: {train_acc:0.2f}')
    print(f'Accuracy on the {test_total} testing samples: {test_acc:0.2f}\n')

  if training_plot:
    plt.plot(train_losses)
    plt.xlabel('Batch')
    plt.ylabel('Training loss')
    plt.show()

  return train_acc, test_acc


def shuffle_and_split_data(X, y, seed):
  """
  Helper function to shuffle and split data

  Args:
    X: torch.tensor
      Input data
    y: torch.tensor
      Corresponding target variables
    seed: int
      Set seed for reproducibility

  Returns:
    X_test: torch.tensor
      Test data [20% of X]
    y_test: torch.tensor
      Labels corresponding to above mentioned test data
    X_train: torch.tensor
      Train data [80% of X]
    y_train: torch.tensor
      Labels corresponding to above mentioned train data
  """
  # Set seed for reproducibility
  torch.manual_seed(seed)
  # Number of samples
  N = X.shape[0]
  # Shuffle data
  shuffled_indices = torch.randperm(N)
  X = X[shuffled_indices]
  y = y[shuffled_indices]

  test_size = int(0.2 * N)
  X_test = X[:test_size]
  y_test = y[:test_size]
  X_train = X[test_size:]
  y_train = y[test_size:]

  return X_test, y_test, X_train, y_train


def sample_grid(M=500, x_max=2.0):
  """
  Helper function to simulate sample meshgrid

  Args:
    M: int
      Size of the constructed tensor with meshgrid
    x_max: float
      Defines range for the set of points

  Returns:
    X_all: torch.tensor
      Concatenated meshgrid tensor
  """
  ii, jj = torch.meshgrid(torch.linspace(-x_max, x_max,M),
                          torch.linspace(-x_max, x_max, M),
                          indexing='ij')
  X_all = torch.cat([ii.unsqueeze(-1),
                     jj.unsqueeze(-1)],
                     dim=-1).view(-1, 2)
  return X_all


def plot_decision_map(X_all, y_pred, X_test, y_test,
                      M=500, x_max=2.0, eps=1e-3):
  """
  Helper function to plot decision map

  Args:
    X_all: torch.tensor
      Concatenated meshgrid tensor
    y_pred: torch.tensor
      Labels predicted by the network
    X_test: torch.tensor
      Test data
    y_test: torch.tensor
      Labels of the test data
    M: int
      Size of the constructed tensor with meshgrid
    x_max: float
      Defines range for the set of points
    eps: float
      Decision threshold

  Returns:
    Nothing
  """
  decision_map = torch.argmax(y_pred, dim=1)

  for i in range(len(X_test)):
    indeces = (X_all[:, 0] - X_test[i, 0])**2 + (X_all[:, 1] - X_test[i, 1])**2 < eps
    decision_map[indeces] = (K + y_test[i]).long()

  decision_map = decision_map.view(M, M).cpu()
  plt.imshow(decision_map, extent=[-x_max, x_max, -x_max, x_max], cmap='jet')
  plt.axis('off')
  plt.plot()


def plot_function_apx(x_vals, relu_activations, predicted_output):
    """
    Visualizes ReLU activations and the resulting function approximation.

    Args:
      x_vals: torch.tensor
        Input x-axis data points.
      relu_activations: torch.tensor
        Calculated ReLU activations along x-axis for each ReLU unit.
      predicted_output: torch.tensor
        Estimated output labels or function approximations (weighted sum of ReLUs).

    Returns:
      None
    """

    fig, axes = plt.subplots(2, 1, figsize=(8, 6))

    ## Plot ReLU activations
    axes[0].plot(x_vals, relu_activations.T)
    axes[0].set_xlabel('x-values', fontsize=12)
    axes[0].set_ylabel('Activation Levels', fontsize=12)
    axes[0].set_title('ReLU Activations (Basis Functions)', fontsize=14)
    relu_labels = [f"ReLU {i + 1}" for i in range(relu_activations.shape[0])]
    axes[0].legend(relu_labels, ncol=2)

    ## Plot the function approximation and the ground truth
    axes[1].plot(x_vals, torch.sin(x_vals), label='Ground Truth (sin(x))', color='g', linewidth=2)
    axes[1].plot(x_vals, predicted_output, label='Predicted Output', linestyle='--', color='r')
    axes[1].set_xlabel('x-values', fontsize=12)
    axes[1].set_ylabel('y(x)', fontsize=12)
    axes[1].set_title('Function Approximation vs Ground Truth', fontsize=14)
    axes[1].legend()

    plt.tight_layout(pad=2)
    plt.show()


def show_images(image, num_row=2, num_col=5):
    # plot images
    image_size = int(np.sqrt(image.shape[-1]))
    image = np.reshape(image, (image.shape[0], image_size, image_size))
    fig, axes = plt.subplots(num_row, num_col, figsize=(1.5*num_col,2*num_row))
    for i in range(num_row*num_col):
        ax = axes[i//num_col, i%num_col]
        ax.imshow(image[i], cmap='gray', vmin=0, vmax=1)
        ax.axis('off')
    plt.tight_layout()
    plt.show()


SEED = 2024
# Call `seed_setter` to ensure reproducibility.
seed_setter(seed=SEED)
# Out:
# Random seed 2024 has been set.

# %% [markdown]
# # Loading the data

# %%
# Load data
mnist_data = fetch_openml("mnist_784")
x = mnist_data["data"].astype('float').to_numpy()
y = mnist_data["target"].astype('int')

# Normalize
x /= 255.0

# One-hot encode labels
num_labels = len(np.unique(y))
y_new = to_categorical(y, num_labels)

x_train, x_test, y_train, y_test = train_test_split(
    x, y_new, train_size=60000, test_size=10000, random_state=42, shuffle=True
)

# %%
print("Training data: {} {}".format(x_train.shape, y_train.shape))
print("Test data: {} {}".format(x_test.shape, y_test.shape))
show_images(x_train)
# Out:
# Training data: (60000, 784) (60000, 10)
# Test data: (10000, 784) (10000, 10)

# %% [markdown]
# # Activation Functions & Optimizers

# %% [markdown]
# There are many activation functions which some of them listed below. In this section you should implement them.
#
# 1. Sigmoid:
# $$
# \operatorname{sigmoid}(x) = \frac{1}{1 + \exp(-x)}
# $$
#
# 2. Softmax: $$\operatorname{softmax}(\mathbf X)_{ij} = \frac{\exp(\mathbf X_{ij})}{\sum_k \exp \mathbf X_{ik})}.$$
#
#
# 3. Tanh (Hyperbolic Tangent):
# $$
# \operatorname{tanh}(x) = \frac{\sinh(x)}{\cosh(x)} = \frac{\exp(x) - \exp(-x)}{\exp(x) + \exp(-x)}
# $$
#
# 4. ReLU: $$\operatorname{ReLU}(x) = \max(0, x)$$
#
# 5. Leaky ReLU:
# $$
# \operatorname{LeakyReLU}(x) =
# \begin{cases}
# x & \text{if } x \geq 0 \\
# \alpha x & \text{if } x < 0
# \end{cases}
# $$
# where \( $\alpha$ \) is a small constant (e.g., 0.01).
#
# 6. ELU (Exponential Linear Unit):
# $$
# \operatorname{ELU}(x) =
# \begin{cases}
# x & \text{if } x > 0 \\
# \alpha (\exp(x) - 1) & \text{if } x \leq 0
# \end{cases}
# $$
# where ($\alpha$) is a positive constant.
#
# 7. SELU (Scaled Exponential Linear Unit):
# $$
# \operatorname{SELU}(x) =
# \lambda
# \begin{cases}
# x & \text{if } x > 0 \\
# \alpha (\exp(x) - 1) & \text{if } x \leq 0
# \end{cases}
# $$
# where \( $\lambda$ \) and \( $\alpha$ \) are predefined constants, typically \( $\lambda \approx 1.0507$ \) and \( $\alpha \approx 1.67326$ \).

# %% [markdown]
# ------
# There are several optimizer algorithms for optimizing the neural network over epochs. You should implement some of those mentioned in this section:
#
# ***Stochastic Gradient Descent (SGD)***
#
# SGD is the basic form of gradient descent, where each weight (\( w \)) and bias (\( b \)) parameter is updated in the opposite direction of its gradient.
#
# **Update Rule:**
# $$
# w^{(t+1)} = w^{(t)} - \eta \cdot \nabla_w L(w^{(t)}, b^{(t)})
# $$
# $$
# b^{(t+1)} = b^{(t)} - \eta \cdot \nabla_b L(w^{(t)}, b^{(t)})
# $$
#
# - \( w \): Weight parameters
# - \( b \): Bias parameters
# - \( $\eta$ \): Learning rate
# - \( $\nabla_w L(w, b)$ \): Gradient of the loss with respect to \( w \)
# - \( $\nabla_b L(w, b)$ \): Gradient of the loss with respect to \( b \)
#
# <br><br>
#
# ***Momentum Optimizer***
#
# Momentum optimizer smooths parameter updates by adding a velocity term to accumulate past gradients.
#
# **Update Rule:**
# 1. **Velocity Update for Weights and Biases:**
#    $$
#    v_w^{(t+1)} = \beta \cdot v_w^{(t)} + (1 - \beta) \cdot \nabla_w L(w^{(t)}, b^{(t)})
#    $$
#    $$
#    v_b^{(t+1)} = \beta \cdot v_b^{(t)} + (1 - \beta) \cdot \nabla_b L(w^{(t)}, b^{(t)})
#    $$
#
# 2. **Parameter Update:**
#    $$
#    w^{(t+1)} = w^{(t)} - \eta \cdot v_w^{(t+1)}
#    $$
#    $$
#    b^{(t+1)} = b^{(t)} - \eta \cdot v_b^{(t+1)}
#    $$
#
# - \( $v_w$ \): Velocity term for weights
# - \( $v_b$ \): Velocity term for biases
# - \( $\beta$ \): Momentum term, typically set to 0.9
#
# <br><br>
#
# ***Adam Optimizer***
#
# Adam combines momentum and adaptive learning rates, using both first (momentum) and second (RMSprop) moment estimates.
#
# **Update Rule:**
# 1. **Compute biased first and second moment estimates:**
#    $$
#    m_w^{(t+1)} = \beta_1 \cdot m_w^{(t)} + (1 - \beta_1) \cdot \nabla_w L(w^{(t)}, b^{(t)})
#    $$
#    $$
#    m_b^{(t+1)} = \beta_1 \cdot m_b^{(t)} + (1 - \beta_1) \cdot \nabla_b L(w^{(t)}, b^{(t)})
#    $$
#    $$
#    v_w^{(t+1)} = \beta_2 \cdot v_w^{(t)} + (1 - \beta_2) \cdot \left( \nabla_w L(w^{(t)}, b^{(t)}) \right)^2
#    $$
#    $$
#    v_b^{(t+1)} = \beta_2 \cdot v_b^{(t)} + (1 - \beta_2) \cdot \left( \nabla_b L(w^{(t)}, b^{(t)}) \right)^2
#    $$
#
# 2. **Compute bias-corrected estimates:**
#    $$
#    \hat{m}_w^{(t+1)} = \frac{m_w^{(t+1)}}{1 - \beta_1^{t+1}}, \quad \hat{m}_b^{(t+1)} = \frac{m_b^{(t+1)}}{1 - \beta_1^{t+1}}
#    $$
#    $$
#    \hat{v}_w^{(t+1)} = \frac{v_w^{(t+1)}}{1 - \beta_2^{t+1}}, \quad \hat{v}_b^{(t+1)} = \frac{v_b^{(t+1)}}{1 - \beta_2^{t+1}}
#    $$
#
# 3. **Parameter Update:**
#    $$
#    w^{(t+1)} = w^{(t)} - \eta \cdot \frac{\hat{m}_w^{(t+1)}}{\sqrt{\hat{v}_w^{(t+1)}} + \epsilon}
#    $$
#    $$
#    b^{(t+1)} = b^{(t)} - \eta \cdot \frac{\hat{m}_b^{(t+1)}}{\sqrt{\hat{v}_b^{(t+1)}} + \epsilon}
#    $$
#
# - \( $m_w$ \), \( $m_b$ \): First moment estimates (mean of gradients) for weights and biases
# - \( $v_w$ \), \( $v_b$ \): Second moment estimates (uncentered variance of gradients) for weights and biases
# - \( $\beta_1$ \): Decay rate for first moment, typically 0.9
# - \( $\beta_2$ \): Decay rate for second moment, typically 0.999
# - \( $\epsilon$ \): Small constant for numerical stability (e.g., \(10^{-8}\))

# %% [markdown]
# # MLP from Scratch

# %%
class MLP():
    def __init__(self, sizes, activation='sigmoid'):
        self.sizes = sizes
        self.num_layers = len(sizes) - 1  # number of layers excluding input
        self.activation_name = activation

        # Choose activation function
        if activation == 'relu':
            self.activation = self.relu
        elif activation == 'sigmoid':
            self.activation = self.sigmoid
        elif activation == 'tanh':
            self.activation = self.tanh
        elif activation == 'leaky_relu':
            self.activation = self.leaky_relu
        elif activation == 'elu':
            self.activation = self.elu
        elif activation == 'selu':
            self.activation = self.selu

        else:
            raise ValueError("This activation function is currently not supported!")

        # Save all weights
        self.params = self.initialize()
        # Save all intermediate values, i.e. activations
        self.cache = {}

    # Activation functions remain the same as defined in your original code
    def relu(self, x, derivative=False):
        '''
            Forward path:
            relu(x) = max(0, x)
            In other word,
            relu(x) = 0, if x < 0
                    = x, if x >= 0

            Backward path:
            ∇relu(x) = 0, if x < 0
                     = 1, if x >=0
        '''
        # -------------------------------- TODO -------------------------------------
        if derivative:
            return (x > 0).astype(float)
        else:
            return np.maximum(0, x)
        # -------------------------------- TODO -------------------------------------

    def tanh(self, x, derivative=False):
        '''
            Forward path:
            tanh(x) = (exp(x) - exp(-x)) / (exp(x) + exp(-x))

            Backward path:
            ∇tanh(x) = 1 - tanh(x)^2
        '''
        # -------------------------------- TODO -------------------------------------
        if derivative:
            tanh_x = np.tanh(x)
            return 1 - tanh_x**2
        else:
            return np.tanh(x)
        # -------------------------------- TODO -------------------------------------

    def sigmoid(self, x, derivative=False):
        '''
            Forward path:
            σ(x) = 1 / 1+exp(-z)

            Backward path:
            ∇σ(x) = exp(-z) / (1+exp(-z))^2
        '''
        # -------------------------------- TODO -------------------------------------
        if derivative:
            sigmoid_x = 1 / (1 + np.exp(-x))
            return sigmoid_x * (1 - sigmoid_x)
        else:
            return 1 / (1 + np.exp(-x))
        # -------------------------------- TODO -------------------------------------

    def softmax(self, x):
        '''
            softmax(x) = exp(x) / ∑exp(x)
        '''
        # -------------------------------- TODO -------------------------------------
        x_shifted = x - np.max(x, axis=-1, keepdims=True)
        exp_x = np.exp(x_shifted)
        softmax_x = exp_x / np.sum(exp_x, axis=-1, keepdims=True)
        return softmax_x
        # -------------------------------- TODO -------------------------------------


    def leaky_relu(self, x, alpha=0.01, derivative=False):
        '''
            Forward path:
            leaky_relu(x) = x if x >= 0 else αx

            Backward path:
            ∇leaky_relu(x) = 1 if x >= 0 else α
        '''
        # -------------------------------- TODO -------------------------------------
        if derivative:
            grad = np.ones_like(x)
            grad[x < 0] = alpha
            return grad
        else:
            return np.where(x >= 0, x, alpha * x)
        # -------------------------------- TODO -------------------------------------

    def elu(self, x, alpha=1.0, derivative=False):
        '''
            Forward path:
            elu(x) = x if x > 0 else α(exp(x) - 1)

            Backward path:
            ∇elu(x) = 1 if x > 0 else α * exp(x)
        '''
        # -------------------------------- TODO -------------------------------------
        if derivative:
            grad = np.where(x > 0, 1, alpha * np.exp(x))
            return grad
        else:
            return np.where(x > 0, x, alpha * (np.exp(x) - 1))
        # -------------------------------- TODO -------------------------------------

    def selu(self, x, lambda_=1.0507, alpha=1.67326, derivative=False):
        '''
            Forward path:
            selu(x) = λ * (x if x > 0 else α * (exp(x) - 1))

            Backward path:
            ∇selu(x) = λ * (1 if x > 0 else α * exp(x))
        '''
        # -------------------------------- TODO -------------------------------------
        if derivative:
            grad = lambda_ * np.where(x > 0, 1, alpha * np.exp(x))
            return grad
        else:
            return lambda_ * np.where(x > 0, x, alpha * (np.exp(x) - 1))
        # -------------------------------- TODO -------------------------------------

    def initialize(self):
        params = {}
        for i in range(1, self.num_layers + 1):
            input_layer = self.sizes[i - 1]
            output_layer = self.sizes[i]
            params[f"W{i}"] = np.random.randn(output_layer, input_layer) * np.sqrt(1. / input_layer)
            params[f"b{i}"] = np.zeros((output_layer, 1))
        return params

    def feed_forward(self, x):
        self.cache["A0"] = x.T
        for i in range(1, self.num_layers + 1):

            W = self.params[f"W{i}"]
            b = self.params[f"b{i}"]

            Z = np.dot(W, self.cache[f"A{i-1}"]) + b
            self.cache[f"Z{i}"] = Z

            if i == self.num_layers:
                A = self.softmax(Z.T).T
            else:
                A = self.activation(Z)
            self.cache[f"A{i}"] = A

        return self.cache[f"A{self.num_layers}"]

    def back_propagate(self, y, output):
        current_batch_size = y.shape[0]
        grads = {}

        # -------------------------------- TODO -------------------------------------
        dA = -(y.T - output)

        for l in range(self.num_layers, 0, -1):
          Z = self.cache[f"Z{l}"]
          if self.activation_name == 'softmax' and l == self.num_layers:
            dZ = dA
          else:
            dZ = dA * self.activation(Z, derivative=True)

          dW = (1 / current_batch_size) * (dZ @ self.cache[f"A{l-1}"].T)
          db = (1 / current_batch_size) * np.sum(dZ, axis=1, keepdims=True)


          grads[f"dW{l}"] = dW
          grads[f"db{l}"] = db

          if l > 1:
            dA = self.params[f"W{l}"].T @ dZ
        # -------------------------------- TODO -------------------------------------

        self.grads = grads
        return self.grads


    def cross_entropy_loss(self, y, output):
        '''
            L(y, ŷ) = −∑ylog(ŷ).
        '''
        # -------------------------------- TODO -------------------------------------
        y = y.T
        output = np.clip(output, 1e-12, 1.0)

        return -np.mean(np.sum(y * np.log(output), axis=1))
        # -------------------------------- TODO -------------------------------------

    def initialize_momemtum_optimizer(self):
        momentum_opt = {}
        for i in range(1, self.num_layers + 1):
            momentum_opt[f"vW{i}"] = np.zeros_like(self.params[f"W{i}"])
            momentum_opt[f"vb{i}"] = np.zeros_like(self.params[f"b{i}"])
        return momentum_opt

    def initialize_adam_optimizer(self):
        adam_opt = {}
        for i in range(1, self.num_layers + 1):
            adam_opt[f"mW{i}"] = np.zeros_like(self.params[f"W{i}"])
            adam_opt[f"vW{i}"] = np.zeros_like(self.params[f"W{i}"])
            adam_opt[f"mb{i}"] = np.zeros_like(self.params[f"b{i}"])
            adam_opt[f"vb{i}"] = np.zeros_like(self.params[f"b{i}"])
        return adam_opt

    def optimize(self, l_rate=0.1, beta=.9, beta1=0.9, beta2=0.999, epsilon=1e-8, t=1):

      if self.optimizer == "sgd":
          for i in range(1, self.num_layers + 1):
              # SGD update rule for weights and biases
              self.params[f"W{i}"] -= l_rate * self.grads[f"dW{i}"]
              self.params[f"b{i}"] -= l_rate * self.grads[f"db{i}"]

      elif self.optimizer == "momentum":
          for i in range(1, self.num_layers + 1):
              # Update momentum terms for weights and biases
              self.momentum_opt[f"vW{i}"] = beta * self.momentum_opt[f"vW{i}"] + (1 - beta) * self.grads[f"dW{i}"]
              self.momentum_opt[f"vb{i}"] = beta * self.momentum_opt[f"vb{i}"] + (1 - beta) * self.grads[f"db{i}"]

              # Update weights and biases using momentum
              self.params[f"W{i}"] -= l_rate * self.momentum_opt[f"vW{i}"]
              self.params[f"b{i}"] -= l_rate * self.momentum_opt[f"vb{i}"]

      elif self.optimizer == "adam":
          for i in range(1, self.num_layers + 1):
              self.adam_opt[f"mW{i}"] = beta1 * self.adam_opt[f"mW{i}"] + (1 - beta1) * self.grads[f"dW{i}"]
              self.adam_opt[f"vW{i}"] = beta2 * self.adam_opt[f"vW{i}"] + (1 - beta2) * np.square(self.grads[f"dW{i}"])
              self.adam_opt[f"mb{i}"] = beta1 * self.adam_opt[f"mb{i}"] + (1 - beta1) * self.grads[f"db{i}"]
              self.adam_opt[f"vb{i}"] = beta2 * self.adam_opt[f"vb{i}"] + (1 - beta2) * np.square(self.grads[f"db{i}"])

              mW_hat = self.adam_opt[f"mW{i}"] / (1 - beta1 ** t)
              vW_hat = self.adam_opt[f"vW{i}"] / (1 - beta2 ** t)
              mb_hat = self.adam_opt[f"mb{i}"] / (1 - beta1 ** t)
              vb_hat = self.adam_opt[f"vb{i}"] / (1 - beta2 ** t)

              self.params[f"W{i}"] -= l_rate * mW_hat / (np.sqrt(vW_hat) + epsilon)
              self.params[f"b{i}"] -= l_rate * mb_hat / (np.sqrt(vb_hat) + epsilon)

      else:
          raise ValueError("This optimizer is currently not supported!")

    # Accuracy, loss, and training methods remain the same as defined in your original code


    def accuracy(self, y, output):
        # -------------------------------- TODO -------------------------------------
         return np.mean(np.argmax(y, axis=1) == np.argmax(output, axis=0))
        # -------------------------------- TODO -------------------------------------

    def train(self, x_train, y_train, x_val, y_val, epochs=10,
              batch_size=64, optimizer='momentum', l_rate=0.1, beta=.9, beta1=0.9, beta2=0.999, epsilon=1e-8, t=1):
        self.epochs = epochs
        self.batch_size = batch_size
        num_batches = -(-x_train.shape[0] // self.batch_size)

        self.optimizer = optimizer
        if self.optimizer == 'momentum':
          self.momentum_opt = self.initialize_momemtum_optimizer()
        elif self.optimizer == 'adam':
          self.adam_opt = self.initialize_adam_optimizer()

        start_time = time.time()

        for i in range(self.epochs):
            permutation = np.random.permutation(x_train.shape[0])
            x_train_shuffled = x_train[permutation]
            y_train_shuffled = y_train[permutation]

            for j in range(num_batches):
                begin = j * self.batch_size
                end = min(begin + self.batch_size, x_train.shape[0]-1)
                x = x_train_shuffled[begin:end]
                y = y_train_shuffled[begin:end]

                output = self.feed_forward(x)
                grad = self.back_propagate(y, output)
                self.optimize(l_rate=l_rate, beta=beta, beta1=beta1, beta2=beta2, epsilon=epsilon, t=t)

            output = self.feed_forward(x_train)
            train_acc = self.accuracy(y_train, output)
            train_loss = self.cross_entropy_loss(y_train, output)
            output = self.feed_forward(x_val)
            val_acc = self.accuracy(y_val, output)
            val_loss = self.cross_entropy_loss(y_val, output)
            print(f'Epoch {i+1}: {time.time()-start_time:.2f}s, train acc={train_acc:.2f}, train loss={train_loss:.2f}, '
                      f'validation acc={val_acc:.2f}, validation loss={val_loss:.2f}')

    def evaluate(self, x_test, y_test):
        output = self.feed_forward(x_test)
        test_acc = self.accuracy(y_test, output)
        test_loss = self.cross_entropy_loss(y_test, output)
        print(f'\nTest acc={test_acc:.2f}, Test loss={test_loss:.2f}')

# %% [markdown]
# Please run experiments with different combinations of optimizers (SGD, Momentum, and Adam) and activation functions (ReLU, Sigmoid, Tanh, Leaky ReLU, SELU, and ELU) over 20 epochs each. Consider networks with three layers (without input layer) whose number of neurons is 128, 64 and 10 respectively. Also consider two learning rates 0.01 and 0.001.
#
#
# After testing all combinations, report which combination of optimizer, activation function, and learning rate performs best.

# %%
import numpy as np
import matplotlib.pyplot as plt

optimizers = ["sgd", "momentum", "adam"]
activations = ["relu", "sigmoid", "tanh", "leaky_relu", "selu", "elu"]
learning_rates = [0.01, 0.001]
epochs = 20

sizes = [784, 128, 64, 10]

results = []

def run_experiment(optimizer, activation, learning_rate, epochs=20):
    mlp = MLP(sizes=sizes, activation=activation)
    mlp.train(x_train,y_train,x_val=x_test,y_val=y_test,epochs=20,optimizer=optimizer,l_rate=learning_rate)
    mlp.optimizer = optimizer
    accuracies = []

    for epoch in range(epochs):
        output = mlp.feed_forward(x_train)
        mlp.back_propagate(y_train, output)

        mlp.optimize(l_rate=learning_rate)

        accuracy = mlp.accuracy(y_train, output)
        accuracies.append(accuracy)

    return accuracies

for optimizer in optimizers:
    for activation in activations:
        for learning_rate in learning_rates:
            print(f"Running experiment: Optimizer={optimizer}, Activation={activation}, Learning Rate={learning_rate}")
            accuracies = run_experiment(optimizer, activation, learning_rate)
            results.append((optimizer, activation, learning_rate, accuracies))


best_result = None
best_accuracy = -1

for result in results:
    optimizer, activation, learning_rate, accuracies = result
    final_accuracy = accuracies[-1]
    if final_accuracy > best_accuracy:
        best_accuracy = final_accuracy
        best_result = result

print(f"Best combination: Optimizer={best_result[0]}, Activation={best_result[1]}, Learning Rate={best_result[2]}")
print(f"Final accuracy: {best_accuracy}")


plt.figure(figsize=(10, 6))
for result in results:
    optimizer, activation, learning_rate, accuracies = result
    label = f"{optimizer} - {activation} -   lr={learning_rate}"
    plt.plot(accuracies, label=label)

plt.title("Training Accuracy for Different Optimizer and Activation Function Combinations")
plt.xlabel("Epochs")
plt.ylabel("Accuracy")
plt.legend(loc="upper left", bbox_to_anchor=(1, 1))
plt.show()
# Out:
# Running experiment: Optimizer=sgd, Activation=relu, Learning Rate=0.01
# Epoch 1: 6.26s, train acc=0.69, train loss=6631.54, validation acc=0.69, validation loss=1085.49
# Epoch 2: 9.26s, train acc=0.72, train loss=5260.85, validation acc=0.73, validation loss=858.66
# Epoch 3: 11.73s, train acc=0.74, train loss=4650.35, validation acc=0.75, validation loss=758.99
# Epoch 4: 14.17s, train acc=0.75, train loss=4364.35, validation acc=0.76, validation loss=713.60
# Epoch 5: 16.86s, train acc=0.76, train loss=4131.32, validation acc=0.77, validation loss=675.99
# Epoch 6: 21.39s, train acc=0.77, train loss=3953.35, validation acc=0.78, validation loss=649.14
# Epoch 7: 23.87s, train acc=0.77, train loss=3829.44, validation acc=0.78, validation loss=630.19
# Epoch 8: 26.31s, train acc=0.79, train loss=3668.05, validation acc=0.79, validation loss=604.65
# Epoch 9: 28.72s, train acc=0.78, train loss=3644.49, validation acc=0.79, validation loss=600.88
# Epoch 10: 31.56s, train acc=0.79, train loss=3491.81, validation acc=0.80, validation loss=577.13
# Epoch 11: 35.72s, train acc=0.79, train loss=3445.32, validation acc=0.80, validation loss=570.77
# Epoch 12: 38.16s, train acc=0.80, train loss=3358.86, validation acc=0.80, validation loss=555.63
# Epoch 13: 40.60s, train acc=0.80, train loss=3371.43, validation acc=0.80, validation loss=558.67
# Epoch 14: 43.03s, train acc=0.81, train loss=3120.42, validation acc=0.81, validation loss=520.46
# Epoch 15: 45.85s, train acc=0.81, train loss=3063.16, validation acc=0.82, validation loss=511.37
# Epoch 16: 50.09s, train acc=0.81, train loss=3072.18, validation acc=0.81, validation loss=512.21
# Epoch 17: 53.93s, train acc=0.81, train loss=3043.86, validation acc=0.82, validation loss=509.17
# Epoch 18: 56.42s, train acc=0.82, train loss=2892.55, validation acc=0.82, validation loss=484.97
# Epoch 19: 58.90s, train acc=0.82, train loss=2899.66, validation acc=0.82, validation loss=486.08
# Epoch 20: 63.68s, train acc=0.82, train loss=2824.54, validation acc=0.83, validation loss=475.00
# Running experiment: Optimizer=sgd, Activation=relu, Learning Rate=0.001
# Epoch 1: 4.16s, train acc=0.34, train loss=13005.90, validation acc=0.34, validation loss=2167.17
# Epoch 2: 7.11s, train acc=0.47, train loss=11720.82, validation acc=0.47, validation loss=1953.91
# Epoch 3: 9.54s, train acc=0.61, train loss=10060.65, validation acc=0.60, validation loss=1677.49
# Epoch 4: 11.98s, train acc=0.68, train loss=8582.75, validation acc=0.68, validation loss=1430.79
# Epoch 5: 14.46s, train acc=0.72, train loss=7530.98, validation acc=0.72, validation loss=1255.48
# Epoch 6: 18.54s, train acc=0.75, train loss=6833.64, validation acc=0.76, validation loss=1138.49
# Epoch 7: 21.52s, train acc=0.77, train loss=6337.93, validation acc=0.77, validation loss=1056.01
# Epoch 8: 23.98s, train acc=0.78, train loss=5965.97, validation acc=0.78, validation loss=993.97
# Epoch 9: 26.42s, train acc=0.79, train loss=5679.51, validation acc=0.79, validation loss=945.72
# Epoch 10: 28.88s, train acc=0.79, train loss=5461.18, validation acc=0.80, validation loss=909.82
# Epoch 11: 33.14s, train acc=0.80, train loss=5274.71, validation acc=0.80, validation loss=878.32
# Epoch 12: 36.03s, train acc=0.80, train loss=5126.24, validation acc=0.80, validation loss=853.68
# Epoch 13: 38.48s, train acc=0.81, train loss=5015.55, validation acc=0.81, validation loss=835.51
# Epoch 14: 40.96s, train acc=0.81, train loss=4908.19, validation acc=0.81, validation loss=817.48
# Epoch 15: 43.41s, train acc=0.81, train loss=4803.92, validation acc=0.81, validation loss=799.90
# Epoch 16: 47.90s, train acc=0.81, train loss=4725.02, validation acc=0.81, validation loss=787.15
# Epoch 17: 50.66s, train acc=0.81, train loss=4661.74, validation acc=0.82, validation loss=776.47
# Epoch 18: 53.15s, train acc=0.82, train loss=4604.07, validation acc=0.82, validation loss=766.78
# Epoch 19: 55.59s, train acc=0.82, train loss=4538.77, validation acc=0.82, validation loss=756.04
# Epoch 20: 58.02s, train acc=0.82, train loss=4497.64, validation acc=0.82, validation loss=749.60
# Running experiment: Optimizer=sgd, Activation=sigmoid, Learning Rate=0.01
# Epoch 1: 3.11s, train acc=0.12, train loss=13721.15, validation acc=0.12, validation loss=2286.50
# Epoch 2: 8.68s, train acc=0.17, train loss=13654.15, validation acc=0.17, validation loss=2275.81
# Epoch 3: 11.90s, train acc=0.15, train loss=13581.69, validation acc=0.16, validation loss=2263.69
# Epoch 4: 15.05s, train acc=0.26, train loss=13500.68, validation acc=0.26, validation loss=2250.05
# Epoch 5: 18.24s, train acc=0.40, train loss=13408.35, validation acc=0.40, validation loss=2234.66
# Epoch 6: 23.58s, train acc=0.46, train loss=13299.99, validation acc=0.46, validation loss=2217.23
# Epoch 7: 26.70s, train acc=0.49, train loss=13171.53, validation acc=0.49, validation loss=2195.82
# Epoch 8: 29.87s, train acc=0.52, train loss=13015.54, validation acc=0.52, validation loss=2169.74
# Epoch 9: 33.38s, train acc=0.57, train loss=12825.21, validation acc=0.57, validation loss=2138.19
# Epoch 10: 38.12s, train acc=0.58, train loss=12594.25, validation acc=0.58, validation loss=2099.82
# Epoch 11: 41.29s, train acc=0.60, train loss=12312.89, validation acc=0.60, validation loss=2052.98
# Epoch 12: 44.41s, train acc=0.62, train loss=11977.22, validation acc=0.61, validation loss=1997.44
# Epoch 13: 48.53s, train acc=0.62, train loss=11584.03, validation acc=0.62, validation loss=1931.93
# Epoch 14: 52.76s, train acc=0.63, train loss=11142.29, validation acc=0.62, validation loss=1858.45
# Epoch 15: 55.90s, train acc=0.64, train loss=10665.05, validation acc=0.64, validation loss=1779.15
# Epoch 16: 59.04s, train acc=0.64, train loss=10173.28, validation acc=0.64, validation loss=1697.23
# Epoch 17: 63.43s, train acc=0.66, train loss=9687.31, validation acc=0.65, validation loss=1616.37
# Epoch 18: 67.34s, train acc=0.68, train loss=9223.29, validation acc=0.67, validation loss=1538.53
# Epoch 19: 70.49s, train acc=0.69, train loss=8791.17, validation acc=0.68, validation loss=1466.73
# Epoch 20: 73.67s, train acc=0.70, train loss=8390.78, validation acc=0.70, validation loss=1399.89
# Running experiment: Optimizer=sgd, Activation=sigmoid, Learning Rate=0.001
# Epoch 1: 3.29s, train acc=0.11, train loss=14052.36, validation acc=0.10, validation loss=2347.06
# Epoch 2: 6.47s, train acc=0.11, train loss=13916.20, validation acc=0.10, validation loss=2322.53
# Epoch 3: 10.64s, train acc=0.11, train loss=13851.27, validation acc=0.10, validation loss=2310.54
# Epoch 4: 15.09s, train acc=0.11, train loss=13819.36, validation acc=0.10, validation loss=2304.48
# Epoch 5: 18.25s, train acc=0.11, train loss=13802.18, validation acc=0.12, validation loss=2301.15
# Epoch 6: 21.49s, train acc=0.11, train loss=13791.54, validation acc=0.12, validation loss=2299.09
# Epoch 7: 26.43s, train acc=0.11, train loss=13783.67, validation acc=0.12, validation loss=2297.59
# Epoch 8: 30.06s, train acc=0.11, train loss=13776.95, validation acc=0.12, validation loss=2296.38
# Epoch 9: 33.19s, train acc=0.11, train loss=13770.65, validation acc=0.12, validation loss=2295.26
# Epoch 10: 36.34s, train acc=0.11, train loss=13764.56, validation acc=0.12, validation loss=2294.21
# Epoch 11: 41.75s, train acc=0.11, train loss=13758.54, validation acc=0.12, validation loss=2293.17
# Epoch 12: 44.93s, train acc=0.11, train loss=13752.52, validation acc=0.12, validation loss=2292.16
# Epoch 13: 48.10s, train acc=0.11, train loss=13746.50, validation acc=0.12, validation loss=2291.15
# Epoch 14: 51.22s, train acc=0.11, train loss=13740.46, validation acc=0.12, validation loss=2290.14
# Epoch 15: 56.54s, train acc=0.11, train loss=13734.41, validation acc=0.12, validation loss=2289.13
# Epoch 16: 59.67s, train acc=0.11, train loss=13728.33, validation acc=0.12, validation loss=2288.13
# Epoch 17: 62.83s, train acc=0.11, train loss=13722.23, validation acc=0.12, validation loss=2287.12
# Epoch 18: 66.38s, train acc=0.11, train loss=13716.10, validation acc=0.12, validation loss=2286.10
# Epoch 19: 71.36s, train acc=0.11, train loss=13709.93, validation acc=0.12, validation loss=2285.07
# Epoch 20: 74.50s, train acc=0.12, train loss=13703.73, validation acc=0.12, validation loss=2284.05
# Running experiment: Optimizer=sgd, Activation=tanh, Learning Rate=0.01
# Epoch 1: 6.58s, train acc=0.87, train loss=5187.37, validation acc=0.87, validation loss=867.27
# Epoch 2: 11.42s, train acc=0.89, train loss=3869.34, validation acc=0.89, validation loss=650.55
# Epoch 3: 18.37s, train acc=0.90, train loss=3247.77, validation acc=0.90, validation loss=547.93
# Epoch 4: 23.20s, train acc=0.91, train loss=2880.99, validation acc=0.91, validation loss=487.75
# Epoch 5: 28.17s, train acc=0.91, train loss=2631.34, validation acc=0.91, validation loss=446.50
# Epoch 6: 34.87s, train acc=0.92, train loss=2447.43, validation acc=0.91, validation loss=415.90
# Epoch 7: 39.66s, train acc=0.92, train loss=2301.71, validation acc=0.92, validation loss=392.17
# Epoch 8: 46.48s, train acc=0.92, train loss=2178.97, validation acc=0.92, validation loss=371.97
# Epoch 9: 51.31s, train acc=0.92, train loss=2089.88, validation acc=0.92, validation loss=357.23
# Epoch 10: 56.43s, train acc=0.93, train loss=2013.15, validation acc=0.93, validation loss=345.41
# Epoch 11: 63.13s, train acc=0.93, train loss=1934.49, validation acc=0.93, validation loss=332.39
# Epoch 12: 67.96s, train acc=0.93, train loss=1869.89, validation acc=0.93, validation loss=322.19
# Epoch 13: 75.10s, train acc=0.93, train loss=1802.30, validation acc=0.93, validation loss=310.83
# Epoch 14: 79.89s, train acc=0.94, train loss=1759.58, validation acc=0.93, validation loss=304.22
# Epoch 15: 84.99s, train acc=0.94, train loss=1710.91, validation acc=0.93, validation loss=296.59
# Epoch 16: 91.54s, train acc=0.94, train loss=1664.35, validation acc=0.94, validation loss=289.55
# Epoch 17: 96.43s, train acc=0.94, train loss=1625.08, validation acc=0.94, validation loss=282.88
# Epoch 18: 103.57s, train acc=0.94, train loss=1584.57, validation acc=0.94, validation loss=276.33
# Epoch 19: 108.36s, train acc=0.94, train loss=1548.07, validation acc=0.94, validation loss=270.63
# Epoch 20: 117.01s, train acc=0.94, train loss=1505.89, validation acc=0.94, validation loss=264.17
# Running experiment: Optimizer=sgd, Activation=tanh, Learning Rate=0.001
# Epoch 1: 5.10s, train acc=0.65, train loss=10888.05, validation acc=0.65, validation loss=1815.25
# Epoch 2: 9.91s, train acc=0.76, train loss=9159.77, validation acc=0.75, validation loss=1526.47
# Epoch 3: 16.96s, train acc=0.80, train loss=8080.33, validation acc=0.79, validation loss=1346.27
# Epoch 4: 21.77s, train acc=0.82, train loss=7342.28, validation acc=0.81, validation loss=1223.35
# Epoch 5: 27.53s, train acc=0.83, train loss=6798.92, validation acc=0.83, validation loss=1132.81
# Epoch 6: 32.90s, train acc=0.84, train loss=6368.45, validation acc=0.83, validation loss=1061.37
# Epoch 7: 37.68s, train acc=0.85, train loss=6018.73, validation acc=0.84, validation loss=1003.34
# Epoch 8: 44.88s, train acc=0.85, train loss=5721.75, validation acc=0.85, validation loss=954.06
# Epoch 9: 49.71s, train acc=0.86, train loss=5468.09, validation acc=0.86, validation loss=912.15
# Epoch 10: 55.23s, train acc=0.87, train loss=5242.63, validation acc=0.86, validation loss=874.89
# Epoch 11: 61.20s, train acc=0.87, train loss=5045.85, validation acc=0.86, validation loss=842.48
# Epoch 12: 66.04s, train acc=0.87, train loss=4871.70, validation acc=0.87, validation loss=813.63
# Epoch 13: 73.18s, train acc=0.88, train loss=4712.49, validation acc=0.87, validation loss=787.47
# Epoch 14: 78.01s, train acc=0.88, train loss=4571.55, validation acc=0.87, validation loss=764.30
# Epoch 15: 83.30s, train acc=0.88, train loss=4437.25, validation acc=0.87, validation loss=742.12
# Epoch 16: 89.44s, train acc=0.88, train loss=4318.48, validation acc=0.88, validation loss=722.64
# Epoch 17: 94.30s, train acc=0.88, train loss=4208.37, validation acc=0.88, validation loss=704.45
# Epoch 18: 101.44s, train acc=0.89, train loss=4107.00, validation acc=0.88, validation loss=687.80
# Epoch 19: 106.31s, train acc=0.89, train loss=4011.70, validation acc=0.88, validation loss=672.10
# Epoch 20: 111.66s, train acc=0.89, train loss=3925.74, validation acc=0.88, validation loss=658.04
# Running experiment: Optimizer=sgd, Activation=leaky_relu, Learning Rate=0.01
# Epoch 1: 4.16s, train acc=0.72, train loss=5933.25, validation acc=0.71, validation loss=1006.77
# Epoch 2: 6.88s, train acc=0.77, train loss=4105.27, validation acc=0.76, validation loss=699.88
# Epoch 3: 9.56s, train acc=0.90, train loss=2246.93, validation acc=0.90, validation loss=380.05
# Epoch 4: 12.31s, train acc=0.91, train loss=1888.89, validation acc=0.91, validation loss=322.16
# Epoch 5: 17.28s, train acc=0.92, train loss=1693.03, validation acc=0.92, validation loss=291.59
# Epoch 6: 20.07s, train acc=0.93, train loss=1551.37, validation acc=0.92, validation loss=270.62
# Epoch 7: 22.81s, train acc=0.93, train loss=1426.79, validation acc=0.93, validation loss=250.90
# Epoch 8: 25.59s, train acc=0.94, train loss=1326.19, validation acc=0.94, validation loss=234.61
# Epoch 9: 30.31s, train acc=0.94, train loss=1239.78, validation acc=0.94, validation loss=222.76
# Epoch 10: 33.05s, train acc=0.95, train loss=1176.81, validation acc=0.94, validation loss=214.01
# Epoch 11: 35.77s, train acc=0.95, train loss=1120.33, validation acc=0.94, validation loss=205.09
# Epoch 12: 38.52s, train acc=0.95, train loss=1051.18, validation acc=0.95, validation loss=194.72
# Epoch 13: 42.09s, train acc=0.95, train loss=1009.06, validation acc=0.95, validation loss=189.50
# Epoch 14: 46.19s, train acc=0.96, train loss=956.94, validation acc=0.95, validation loss=181.34
# Epoch 15: 48.93s, train acc=0.96, train loss=921.34, validation acc=0.95, validation loss=175.83
# Epoch 16: 51.66s, train acc=0.96, train loss=879.78, validation acc=0.95, validation loss=170.72
# Epoch 17: 54.41s, train acc=0.96, train loss=843.55, validation acc=0.96, validation loss=165.22
# Epoch 18: 59.44s, train acc=0.96, train loss=821.10, validation acc=0.96, validation loss=164.04
# Epoch 19: 62.21s, train acc=0.96, train loss=795.60, validation acc=0.96, validation loss=159.44
# Epoch 20: 64.94s, train acc=0.97, train loss=754.70, validation acc=0.96, validation loss=154.40
# Running experiment: Optimizer=sgd, Activation=leaky_relu, Learning Rate=0.001
# Epoch 1: 3.73s, train acc=0.48, train loss=12742.70, validation acc=0.48, validation loss=2122.87
# Epoch 2: 7.83s, train acc=0.61, train loss=10973.02, validation acc=0.61, validation loss=1828.61
# Epoch 3: 10.62s, train acc=0.68, train loss=8915.59, validation acc=0.69, validation loss=1489.32
# Epoch 4: 13.39s, train acc=0.74, train loss=7401.74, validation acc=0.74, validation loss=1242.02
# Epoch 5: 16.20s, train acc=0.76, train loss=6438.95, validation acc=0.76, validation loss=1085.46
# Epoch 6: 21.08s, train acc=0.78, train loss=5779.49, validation acc=0.77, validation loss=977.49
# Epoch 7: 23.86s, train acc=0.79, train loss=5286.62, validation acc=0.78, validation loss=896.78
# Epoch 8: 26.57s, train acc=0.80, train loss=4884.07, validation acc=0.79, validation loss=829.80
# Epoch 9: 29.28s, train acc=0.80, train loss=4555.59, validation acc=0.80, validation loss=775.01
# Epoch 10: 34.53s, train acc=0.81, train loss=4281.30, validation acc=0.80, validation loss=729.20
# Epoch 11: 37.26s, train acc=0.81, train loss=4053.81, validation acc=0.81, validation loss=691.38
# Epoch 12: 39.98s, train acc=0.82, train loss=3855.81, validation acc=0.81, validation loss=657.97
# Epoch 13: 42.73s, train acc=0.82, train loss=3687.61, validation acc=0.81, validation loss=629.63
# Epoch 14: 46.60s, train acc=0.82, train loss=3536.70, validation acc=0.82, validation loss=604.13
# Epoch 15: 50.28s, train acc=0.83, train loss=3401.56, validation acc=0.82, validation loss=581.54
# Epoch 16: 53.02s, train acc=0.83, train loss=3279.49, validation acc=0.82, validation loss=560.76
# Epoch 17: 55.72s, train acc=0.83, train loss=3168.87, validation acc=0.82, validation loss=542.15
# Epoch 18: 58.57s, train acc=0.83, train loss=3069.97, validation acc=0.83, validation loss=525.02
# Epoch 19: 63.75s, train acc=0.84, train loss=2975.77, validation acc=0.83, validation loss=509.12
# Epoch 20: 66.47s, train acc=0.84, train loss=2893.16, validation acc=0.84, validation loss=494.86
# Running experiment: Optimizer=sgd, Activation=selu, Learning Rate=0.01
# Epoch 1: 3.42s, train acc=0.90, train loss=2262.44, validation acc=0.89, validation loss=384.05
# Epoch 2: 6.88s, train acc=0.91, train loss=1888.25, validation acc=0.91, validation loss=323.75
# Epoch 3: 12.63s, train acc=0.92, train loss=1725.05, validation acc=0.92, validation loss=300.18
# Epoch 4: 16.06s, train acc=0.92, train loss=1641.04, validation acc=0.92, validation loss=290.57
# Epoch 5: 19.51s, train acc=0.93, train loss=1542.43, validation acc=0.92, validation loss=274.27
# Epoch 6: 24.18s, train acc=0.93, train loss=1469.34, validation acc=0.93, validation loss=264.32
# Epoch 7: 28.28s, train acc=0.93, train loss=1391.05, validation acc=0.93, validation loss=253.81
# Epoch 8: 31.68s, train acc=0.94, train loss=1327.25, validation acc=0.93, validation loss=243.73
# Epoch 9: 35.10s, train acc=0.94, train loss=1279.98, validation acc=0.93, validation loss=237.31
# Epoch 10: 40.80s, train acc=0.94, train loss=1220.77, validation acc=0.94, validation loss=229.27
# Epoch 11: 44.18s, train acc=0.95, train loss=1149.45, validation acc=0.94, validation loss=217.55
# Epoch 12: 47.66s, train acc=0.95, train loss=1109.65, validation acc=0.94, validation loss=213.15
# Epoch 13: 51.89s, train acc=0.95, train loss=1043.67, validation acc=0.94, validation loss=201.41
# Epoch 14: 56.42s, train acc=0.95, train loss=1002.84, validation acc=0.95, validation loss=194.02
# Epoch 15: 59.82s, train acc=0.95, train loss=969.78, validation acc=0.95, validation loss=190.24
# Epoch 16: 63.21s, train acc=0.96, train loss=918.26, validation acc=0.95, validation loss=183.92
# Epoch 17: 68.75s, train acc=0.96, train loss=887.17, validation acc=0.95, validation loss=176.48
# Epoch 18: 72.11s, train acc=0.96, train loss=834.61, validation acc=0.95, validation loss=170.48
# Epoch 19: 75.50s, train acc=0.96, train loss=807.90, validation acc=0.95, validation loss=166.64
# Epoch 20: 79.31s, train acc=0.96, train loss=771.02, validation acc=0.95, validation loss=161.58
# Running experiment: Optimizer=sgd, Activation=selu, Learning Rate=0.001
# Epoch 1: 3.39s, train acc=0.77, train loss=6200.45, validation acc=0.77, validation loss=1034.03
# Epoch 2: 8.58s, train acc=0.83, train loss=4370.35, validation acc=0.83, validation loss=729.94
# Epoch 3: 12.54s, train acc=0.86, train loss=3578.31, validation acc=0.85, validation loss=599.38
# Epoch 4: 15.93s, train acc=0.87, train loss=3132.16, validation acc=0.87, validation loss=525.96
# Epoch 5: 19.32s, train acc=0.88, train loss=2847.55, validation acc=0.88, validation loss=479.10
# Epoch 6: 25.18s, train acc=0.88, train loss=2650.73, validation acc=0.88, validation loss=447.23
# Epoch 7: 28.57s, train acc=0.89, train loss=2504.23, validation acc=0.89, validation loss=423.10
# Epoch 8: 32.01s, train acc=0.89, train loss=2391.88, validation acc=0.89, validation loss=404.90
# Epoch 9: 36.50s, train acc=0.90, train loss=2302.75, validation acc=0.89, validation loss=390.45
# Epoch 10: 40.79s, train acc=0.90, train loss=2230.28, validation acc=0.90, validation loss=378.65
# Epoch 11: 44.18s, train acc=0.90, train loss=2168.22, validation acc=0.90, validation loss=368.97
# Epoch 12: 47.58s, train acc=0.90, train loss=2115.96, validation acc=0.90, validation loss=360.38
# Epoch 13: 53.47s, train acc=0.90, train loss=2070.82, validation acc=0.90, validation loss=353.32
# Epoch 14: 56.88s, train acc=0.90, train loss=2031.13, validation acc=0.90, validation loss=346.91
# Epoch 15: 60.29s, train acc=0.91, train loss=1996.03, validation acc=0.91, validation loss=341.37
# Epoch 16: 64.55s, train acc=0.91, train loss=1964.67, validation acc=0.91, validation loss=336.54
# Epoch 17: 69.17s, train acc=0.91, train loss=1935.81, validation acc=0.91, validation loss=331.76
# Epoch 18: 72.61s, train acc=0.91, train loss=1909.95, validation acc=0.91, validation loss=327.86
# Epoch 19: 76.03s, train acc=0.91, train loss=1886.40, validation acc=0.91, validation loss=323.90
# Epoch 20: 81.79s, train acc=0.91, train loss=1864.24, validation acc=0.91, validation loss=320.43
# Running experiment: Optimizer=sgd, Activation=elu, Learning Rate=0.01
# Epoch 1: 3.37s, train acc=0.88, train loss=2668.80, validation acc=0.88, validation loss=448.07
# Epoch 2: 9.25s, train acc=0.90, train loss=2097.74, validation acc=0.90, validation loss=356.45
# Epoch 3: 12.59s, train acc=0.91, train loss=1902.93, validation acc=0.91, validation loss=326.61
# Epoch 4: 15.92s, train acc=0.92, train loss=1787.19, validation acc=0.91, validation loss=309.81
# Epoch 5: 19.86s, train acc=0.92, train loss=1699.49, validation acc=0.92, validation loss=297.16
# Epoch 6: 24.81s, train acc=0.92, train loss=1627.59, validation acc=0.92, validation loss=287.35
# Epoch 7: 28.15s, train acc=0.92, train loss=1573.62, validation acc=0.92, validation loss=277.33
# Epoch 8: 31.57s, train acc=0.93, train loss=1505.07, validation acc=0.92, validation loss=268.35
# Epoch 9: 36.97s, train acc=0.93, train loss=1475.15, validation acc=0.93, validation loss=262.76
# Epoch 10: 40.33s, train acc=0.93, train loss=1393.27, validation acc=0.93, validation loss=251.88
# Epoch 11: 43.74s, train acc=0.94, train loss=1343.82, validation acc=0.93, validation loss=243.84
# Epoch 12: 47.32s, train acc=0.94, train loss=1296.35, validation acc=0.93, validation loss=238.05
# Epoch 13: 52.69s, train acc=0.94, train loss=1236.24, validation acc=0.94, validation loss=228.33
# Epoch 14: 56.13s, train acc=0.94, train loss=1194.20, validation acc=0.94, validation loss=222.76
# Epoch 15: 59.57s, train acc=0.95, train loss=1150.11, validation acc=0.94, validation loss=214.68
# Epoch 16: 64.84s, train acc=0.95, train loss=1111.24, validation acc=0.94, validation loss=208.38
# Epoch 17: 68.39s, train acc=0.95, train loss=1071.66, validation acc=0.94, validation loss=204.50
# Epoch 18: 71.73s, train acc=0.95, train loss=1031.10, validation acc=0.94, validation loss=197.12
# Epoch 19: 75.11s, train acc=0.95, train loss=999.13, validation acc=0.95, validation loss=191.98
# Epoch 20: 80.79s, train acc=0.95, train loss=965.23, validation acc=0.95, validation loss=187.38
# Running experiment: Optimizer=sgd, Activation=elu, Learning Rate=0.001
# Epoch 1: 4.22s, train acc=0.69, train loss=9683.70, validation acc=0.68, validation loss=1614.29
# Epoch 2: 8.73s, train acc=0.77, train loss=7024.22, validation acc=0.77, validation loss=1170.80
# Epoch 3: 12.07s, train acc=0.81, train loss=5439.15, validation acc=0.81, validation loss=906.88
# Epoch 4: 15.42s, train acc=0.83, train loss=4504.11, validation acc=0.83, validation loss=751.83
# Epoch 5: 21.08s, train acc=0.84, train loss=3912.08, validation acc=0.84, validation loss=653.46
# Epoch 6: 24.45s, train acc=0.85, train loss=3507.24, validation acc=0.85, validation loss=586.29
# Epoch 7: 27.82s, train acc=0.86, train loss=3215.43, validation acc=0.86, validation loss=538.11
# Epoch 8: 31.44s, train acc=0.87, train loss=2995.91, validation acc=0.87, validation loss=501.77
# Epoch 9: 36.55s, train acc=0.87, train loss=2825.95, validation acc=0.87, validation loss=473.96
# Epoch 10: 39.92s, train acc=0.88, train loss=2690.62, validation acc=0.88, validation loss=451.69
# Epoch 11: 43.23s, train acc=0.88, train loss=2581.35, validation acc=0.88, validation loss=433.80
# Epoch 12: 48.26s, train acc=0.89, train loss=2491.83, validation acc=0.88, validation loss=419.56
# Epoch 13: 51.98s, train acc=0.89, train loss=2415.47, validation acc=0.89, validation loss=406.92
# Epoch 14: 55.29s, train acc=0.89, train loss=2350.34, validation acc=0.89, validation loss=396.64
# Epoch 15: 58.70s, train acc=0.89, train loss=2293.75, validation acc=0.89, validation loss=387.32
# Epoch 16: 64.38s, train acc=0.89, train loss=2244.84, validation acc=0.89, validation loss=379.52
# Epoch 17: 67.68s, train acc=0.90, train loss=2201.38, validation acc=0.90, validation loss=372.62
# Epoch 18: 71.00s, train acc=0.90, train loss=2162.55, validation acc=0.90, validation loss=366.02
# Epoch 19: 74.76s, train acc=0.90, train loss=2127.48, validation acc=0.90, validation loss=360.66
# Epoch 20: 79.89s, train acc=0.90, train loss=2095.50, validation acc=0.90, validation loss=355.70
# Running experiment: Optimizer=momentum, Activation=relu, Learning Rate=0.01
# Epoch 1: 3.82s, train acc=0.72, train loss=5438.44, validation acc=0.73, validation loss=887.72
# Epoch 2: 8.00s, train acc=0.78, train loss=4109.33, validation acc=0.79, validation loss=669.96
# Epoch 3: 10.84s, train acc=0.79, train loss=3486.94, validation acc=0.80, validation loss=572.80
# Epoch 4: 13.68s, train acc=0.80, train loss=3213.70, validation acc=0.81, validation loss=528.39
# Epoch 5: 16.78s, train acc=0.80, train loss=3013.71, validation acc=0.81, validation loss=498.45
# Epoch 6: 21.59s, train acc=0.81, train loss=2890.17, validation acc=0.81, validation loss=480.83
# Epoch 7: 24.43s, train acc=0.81, train loss=2809.65, validation acc=0.82, validation loss=466.38
# Epoch 8: 27.36s, train acc=0.81, train loss=2735.11, validation acc=0.82, validation loss=455.34
# Epoch 9: 30.24s, train acc=0.81, train loss=2701.76, validation acc=0.82, validation loss=450.90
# Epoch 10: 36.63s, train acc=0.81, train loss=2618.16, validation acc=0.81, validation loss=438.64
# Epoch 11: 40.74s, train acc=0.81, train loss=2543.31, validation acc=0.82, validation loss=427.46
# Epoch 12: 43.69s, train acc=0.81, train loss=2568.97, validation acc=0.82, validation loss=430.08
# Epoch 13: 48.10s, train acc=0.81, train loss=2446.18, validation acc=0.81, validation loss=413.15
# Epoch 14: 51.69s, train acc=0.81, train loss=2448.23, validation acc=0.82, validation loss=415.25
# Epoch 15: 54.66s, train acc=0.82, train loss=2391.52, validation acc=0.82, validation loss=405.22
# Epoch 16: 57.62s, train acc=0.82, train loss=2367.50, validation acc=0.82, validation loss=401.70
# Epoch 17: 61.88s, train acc=0.82, train loss=2326.38, validation acc=0.83, validation loss=396.12
# Epoch 18: 65.96s, train acc=0.82, train loss=2319.82, validation acc=0.82, validation loss=395.35
# Epoch 19: 68.91s, train acc=0.82, train loss=2243.36, validation acc=0.82, validation loss=385.23
# Epoch 20: 71.87s, train acc=0.83, train loss=2231.55, validation acc=0.83, validation loss=382.63
# Running experiment: Optimizer=momentum, Activation=relu, Learning Rate=0.001
# Epoch 1: 2.87s, train acc=0.45, train loss=12930.43, validation acc=0.46, validation loss=2157.72
# Epoch 2: 6.46s, train acc=0.57, train loss=11618.03, validation acc=0.57, validation loss=1940.59
# Epoch 3: 10.75s, train acc=0.62, train loss=10126.03, validation acc=0.62, validation loss=1693.87
# Epoch 4: 13.55s, train acc=0.67, train loss=8883.60, validation acc=0.66, validation loss=1489.72
# Epoch 5: 16.36s, train acc=0.69, train loss=8006.67, validation acc=0.68, validation loss=1345.85
# Epoch 6: 19.14s, train acc=0.70, train loss=7349.15, validation acc=0.69, validation loss=1237.37
# Epoch 7: 24.46s, train acc=0.71, train loss=6710.60, validation acc=0.70, validation loss=1130.16
# Epoch 8: 27.43s, train acc=0.74, train loss=6157.54, validation acc=0.74, validation loss=1035.19
# Epoch 9: 30.28s, train acc=0.76, train loss=5778.83, validation acc=0.76, validation loss=971.63
# Epoch 10: 33.19s, train acc=0.78, train loss=5483.02, validation acc=0.77, validation loss=921.96
# Epoch 11: 38.34s, train acc=0.78, train loss=5252.86, validation acc=0.78, validation loss=883.10
# Epoch 12: 41.20s, train acc=0.79, train loss=5067.95, validation acc=0.78, validation loss=852.58
# Epoch 13: 44.11s, train acc=0.79, train loss=4923.10, validation acc=0.79, validation loss=827.86
# Epoch 14: 47.04s, train acc=0.80, train loss=4797.28, validation acc=0.79, validation loss=806.96
# Epoch 15: 52.34s, train acc=0.80, train loss=4688.33, validation acc=0.79, validation loss=788.65
# Epoch 16: 55.20s, train acc=0.80, train loss=4595.53, validation acc=0.80, validation loss=773.26
# Epoch 17: 58.17s, train acc=0.80, train loss=4523.71, validation acc=0.80, validation loss=760.82
# Epoch 18: 60.99s, train acc=0.81, train loss=4443.94, validation acc=0.80, validation loss=747.80
# Epoch 19: 66.28s, train acc=0.81, train loss=4376.71, validation acc=0.80, validation loss=736.74
# Epoch 20: 69.29s, train acc=0.81, train loss=4319.34, validation acc=0.80, validation loss=727.00
# Running experiment: Optimizer=momentum, Activation=sigmoid, Learning Rate=0.01
# Epoch 1: 3.52s, train acc=0.11, train loss=13733.82, validation acc=0.12, validation loss=2288.66
# Epoch 2: 7.22s, train acc=0.12, train loss=13668.15, validation acc=0.12, validation loss=2278.09
# Epoch 3: 11.55s, train acc=0.22, train loss=13597.95, validation acc=0.22, validation loss=2266.38
# Epoch 4: 16.58s, train acc=0.18, train loss=13518.16, validation acc=0.18, validation loss=2252.95
# Epoch 5: 20.10s, train acc=0.29, train loss=13426.82, validation acc=0.29, validation loss=2237.84
# Epoch 6: 23.79s, train acc=0.34, train loss=13319.79, validation acc=0.34, validation loss=2220.09
# Epoch 7: 29.91s, train acc=0.45, train loss=13193.49, validation acc=0.45, validation loss=2198.99
# Epoch 8: 33.45s, train acc=0.49, train loss=13038.37, validation acc=0.48, validation loss=2173.35
# Epoch 9: 36.97s, train acc=0.54, train loss=12851.47, validation acc=0.53, validation loss=2142.23
# Epoch 10: 42.28s, train acc=0.56, train loss=12622.85, validation acc=0.56, validation loss=2103.98
# Epoch 11: 46.26s, train acc=0.60, train loss=12350.88, validation acc=0.60, validation loss=2059.11
# Epoch 12: 49.88s, train acc=0.59, train loss=12023.29, validation acc=0.58, validation loss=2004.17
# Epoch 13: 53.64s, train acc=0.61, train loss=11649.21, validation acc=0.60, validation loss=1942.03
# Epoch 14: 59.25s, train acc=0.61, train loss=11228.66, validation acc=0.61, validation loss=1871.89
# Epoch 15: 62.76s, train acc=0.64, train loss=10775.71, validation acc=0.63, validation loss=1796.65
# Epoch 16: 66.33s, train acc=0.64, train loss=10295.49, validation acc=0.63, validation loss=1716.71
# Epoch 17: 72.08s, train acc=0.66, train loss=9809.24, validation acc=0.65, validation loss=1635.86
# Epoch 18: 75.67s, train acc=0.68, train loss=9329.99, validation acc=0.67, validation loss=1556.30
# Epoch 19: 79.18s, train acc=0.69, train loss=8874.49, validation acc=0.69, validation loss=1480.36
# Epoch 20: 83.70s, train acc=0.70, train loss=8450.95, validation acc=0.70, validation loss=1409.72
# Running experiment: Optimizer=momentum, Activation=sigmoid, Learning Rate=0.001
# Epoch 1: 3.51s, train acc=0.10, train loss=13992.08, validation acc=0.10, validation loss=2329.46
# Epoch 2: 8.56s, train acc=0.10, train loss=13875.75, validation acc=0.10, validation loss=2310.90
# Epoch 3: 12.82s, train acc=0.10, train loss=13821.37, validation acc=0.10, validation loss=2302.38
# Epoch 4: 16.34s, train acc=0.12, train loss=13794.33, validation acc=0.12, validation loss=2298.23
# Epoch 5: 19.93s, train acc=0.11, train loss=13779.03, validation acc=0.12, validation loss=2295.90
# Epoch 6: 26.32s, train acc=0.11, train loss=13768.92, validation acc=0.12, validation loss=2294.38
# Epoch 7: 31.50s, train acc=0.11, train loss=13760.96, validation acc=0.12, validation loss=2293.15
# Epoch 8: 35.90s, train acc=0.11, train loss=13753.91, validation acc=0.12, validation loss=2292.05
# Epoch 9: 40.76s, train acc=0.11, train loss=13747.23, validation acc=0.12, validation loss=2290.98
# Epoch 10: 44.26s, train acc=0.11, train loss=13740.72, validation acc=0.12, validation loss=2289.93
# Epoch 11: 47.85s, train acc=0.11, train loss=13734.26, validation acc=0.12, validation loss=2288.88
# Epoch 12: 53.74s, train acc=0.11, train loss=13727.79, validation acc=0.12, validation loss=2287.83
# Epoch 13: 57.33s, train acc=0.11, train loss=13721.32, validation acc=0.12, validation loss=2286.75
# Epoch 14: 60.94s, train acc=0.11, train loss=13714.83, validation acc=0.12, validation loss=2285.68
# Epoch 15: 66.49s, train acc=0.11, train loss=13708.31, validation acc=0.12, validation loss=2284.62
# Epoch 16: 70.29s, train acc=0.11, train loss=13701.76, validation acc=0.12, validation loss=2283.52
# Epoch 17: 73.84s, train acc=0.11, train loss=13695.17, validation acc=0.12, validation loss=2282.42
# Epoch 18: 77.57s, train acc=0.11, train loss=13688.53, validation acc=0.12, validation loss=2281.31
# Epoch 19: 83.11s, train acc=0.12, train loss=13681.86, validation acc=0.12, validation loss=2280.22
# Epoch 20: 86.66s, train acc=0.12, train loss=13675.15, validation acc=0.12, validation loss=2279.09
# Running experiment: Optimizer=momentum, Activation=tanh, Learning Rate=0.01
# Epoch 1: 6.22s, train acc=0.86, train loss=5274.66, validation acc=0.86, validation loss=881.87
# Epoch 2: 11.49s, train acc=0.89, train loss=3955.12, validation acc=0.89, validation loss=662.81
# Epoch 3: 19.07s, train acc=0.90, train loss=3315.80, validation acc=0.90, validation loss=557.75
# Epoch 4: 24.36s, train acc=0.91, train loss=2937.07, validation acc=0.90, validation loss=494.99
# Epoch 5: 31.93s, train acc=0.91, train loss=2676.80, validation acc=0.91, validation loss=452.39
# Epoch 6: 37.20s, train acc=0.91, train loss=2488.11, validation acc=0.92, validation loss=420.62
# Epoch 7: 43.72s, train acc=0.92, train loss=2344.21, validation acc=0.92, validation loss=396.71
# Epoch 8: 49.30s, train acc=0.92, train loss=2221.67, validation acc=0.92, validation loss=376.51
# Epoch 9: 54.62s, train acc=0.92, train loss=2121.33, validation acc=0.92, validation loss=361.19
# Epoch 10: 62.03s, train acc=0.93, train loss=2046.00, validation acc=0.93, validation loss=348.47
# Epoch 11: 67.30s, train acc=0.93, train loss=1962.35, validation acc=0.93, validation loss=335.07
# Epoch 12: 74.80s, train acc=0.93, train loss=1895.38, validation acc=0.93, validation loss=324.17
# Epoch 13: 80.06s, train acc=0.93, train loss=1842.37, validation acc=0.93, validation loss=315.86
# Epoch 14: 87.00s, train acc=0.93, train loss=1784.38, validation acc=0.93, validation loss=306.31
# Epoch 15: 92.26s, train acc=0.94, train loss=1733.93, validation acc=0.93, validation loss=298.55
# Epoch 16: 97.76s, train acc=0.94, train loss=1695.60, validation acc=0.93, validation loss=292.64
# Epoch 17: 104.85s, train acc=0.94, train loss=1647.88, validation acc=0.93, validation loss=284.96
# Epoch 18: 110.08s, train acc=0.94, train loss=1610.32, validation acc=0.94, validation loss=278.94
# Epoch 19: 117.61s, train acc=0.94, train loss=1569.68, validation acc=0.94, validation loss=272.80
# Epoch 20: 122.85s, train acc=0.94, train loss=1534.17, validation acc=0.94, validation loss=267.05
# Running experiment: Optimizer=momentum, Activation=tanh, Learning Rate=0.001
# Epoch 1: 6.59s, train acc=0.69, train loss=10589.32, validation acc=0.69, validation loss=1765.30
# Epoch 2: 12.38s, train acc=0.78, train loss=8873.60, validation acc=0.78, validation loss=1479.63
# Epoch 3: 17.76s, train acc=0.81, train loss=7875.08, validation acc=0.81, validation loss=1313.66
# Epoch 4: 25.11s, train acc=0.83, train loss=7199.71, validation acc=0.82, validation loss=1201.50
# Epoch 5: 30.36s, train acc=0.84, train loss=6689.03, validation acc=0.84, validation loss=1116.91
# Epoch 6: 39.84s, train acc=0.85, train loss=6284.27, validation acc=0.84, validation loss=1049.69
# Epoch 7: 45.14s, train acc=0.85, train loss=5949.84, validation acc=0.85, validation loss=994.27
# Epoch 8: 51.64s, train acc=0.86, train loss=5667.36, validation acc=0.86, validation loss=947.53
# Epoch 9: 57.36s, train acc=0.86, train loss=5419.19, validation acc=0.86, validation loss=906.42
# Epoch 10: 62.58s, train acc=0.87, train loss=5203.83, validation acc=0.86, validation loss=870.76
# Epoch 11: 69.96s, train acc=0.87, train loss=5012.43, validation acc=0.87, validation loss=839.14
# Epoch 12: 75.17s, train acc=0.87, train loss=4843.19, validation acc=0.87, validation loss=810.92
# Epoch 13: 82.67s, train acc=0.88, train loss=4686.14, validation acc=0.87, validation loss=785.03
# Epoch 14: 88.06s, train acc=0.88, train loss=4548.26, validation acc=0.87, validation loss=762.44
# Epoch 15: 95.73s, train acc=0.88, train loss=4421.18, validation acc=0.88, validation loss=741.20
# Epoch 16: 101.08s, train acc=0.88, train loss=4304.22, validation acc=0.88, validation loss=721.94
# Epoch 17: 107.07s, train acc=0.88, train loss=4195.71, validation acc=0.88, validation loss=704.10
# Epoch 18: 113.09s, train acc=0.89, train loss=4092.77, validation acc=0.88, validation loss=686.88
# Epoch 19: 118.36s, train acc=0.89, train loss=4003.06, validation acc=0.88, validation loss=672.18
# Epoch 20: 125.92s, train acc=0.89, train loss=3916.74, validation acc=0.89, validation loss=657.91
# Running experiment: Optimizer=momentum, Activation=leaky_relu, Learning Rate=0.01
# Epoch 1: 3.09s, train acc=0.80, train loss=4642.99, validation acc=0.80, validation loss=776.14
# Epoch 2: 6.48s, train acc=0.89, train loss=2385.59, validation acc=0.89, validation loss=402.69
# Epoch 3: 11.94s, train acc=0.91, train loss=1951.18, validation acc=0.91, validation loss=333.94
# Epoch 4: 15.10s, train acc=0.92, train loss=1759.96, validation acc=0.92, validation loss=304.64
# Epoch 5: 18.20s, train acc=0.92, train loss=1633.61, validation acc=0.92, validation loss=285.03
# Epoch 6: 21.32s, train acc=0.93, train loss=1545.91, validation acc=0.93, validation loss=271.32
# Epoch 7: 26.75s, train acc=0.93, train loss=1460.09, validation acc=0.93, validation loss=260.58
# Epoch 8: 29.85s, train acc=0.94, train loss=1385.04, validation acc=0.93, validation loss=249.64
# Epoch 9: 32.94s, train acc=0.94, train loss=1317.59, validation acc=0.93, validation loss=238.33
# Epoch 10: 36.09s, train acc=0.94, train loss=1265.19, validation acc=0.94, validation loss=231.94
# Epoch 11: 41.58s, train acc=0.94, train loss=1206.56, validation acc=0.94, validation loss=223.15
# Epoch 12: 44.71s, train acc=0.95, train loss=1163.83, validation acc=0.94, validation loss=217.21
# Epoch 13: 47.85s, train acc=0.95, train loss=1120.93, validation acc=0.94, validation loss=211.30
# Epoch 14: 51.20s, train acc=0.95, train loss=1085.76, validation acc=0.95, validation loss=205.60
# Epoch 15: 56.53s, train acc=0.95, train loss=1041.76, validation acc=0.95, validation loss=199.41
# Epoch 16: 59.68s, train acc=0.96, train loss=1002.52, validation acc=0.95, validation loss=193.05
# Epoch 17: 62.80s, train acc=0.96, train loss=974.82, validation acc=0.95, validation loss=189.17
# Epoch 18: 66.53s, train acc=0.96, train loss=945.14, validation acc=0.95, validation loss=185.13
# Epoch 19: 71.34s, train acc=0.96, train loss=927.68, validation acc=0.95, validation loss=184.32
# Epoch 20: 74.42s, train acc=0.96, train loss=902.95, validation acc=0.95, validation loss=178.89
# Running experiment: Optimizer=momentum, Activation=leaky_relu, Learning Rate=0.001
# Epoch 1: 3.17s, train acc=0.26, train loss=13533.60, validation acc=0.26, validation loss=2257.62
# Epoch 2: 7.54s, train acc=0.39, train loss=12791.29, validation acc=0.39, validation loss=2135.51
# Epoch 3: 11.80s, train acc=0.46, train loss=11772.48, validation acc=0.45, validation loss=1967.96
# Epoch 4: 14.94s, train acc=0.51, train loss=10713.68, validation acc=0.50, validation loss=1793.17
# Epoch 5: 17.99s, train acc=0.55, train loss=9805.14, validation acc=0.54, validation loss=1643.85
# Epoch 6: 22.68s, train acc=0.56, train loss=9021.18, validation acc=0.56, validation loss=1514.32
# Epoch 7: 26.39s, train acc=0.58, train loss=8326.67, validation acc=0.57, validation loss=1399.60
# Epoch 8: 29.48s, train acc=0.66, train loss=7561.19, validation acc=0.66, validation loss=1270.15
# Epoch 9: 32.52s, train acc=0.72, train loss=6634.47, validation acc=0.72, validation loss=1113.03
# Epoch 10: 37.19s, train acc=0.75, train loss=5813.69, validation acc=0.75, validation loss=974.38
# Epoch 11: 40.71s, train acc=0.76, train loss=5083.43, validation acc=0.76, validation loss=852.64
# Epoch 12: 43.80s, train acc=0.85, train loss=3880.44, validation acc=0.85, validation loss=652.58
# Epoch 13: 49.34s, train acc=0.87, train loss=3326.61, validation acc=0.86, validation loss=559.45
# Epoch 14: 54.58s, train acc=0.87, train loss=3008.52, validation acc=0.87, validation loss=505.58
# Epoch 15: 57.63s, train acc=0.88, train loss=2792.07, validation acc=0.87, validation loss=469.76
# Epoch 16: 60.70s, train acc=0.88, train loss=2631.52, validation acc=0.88, validation loss=442.41
# Epoch 17: 63.99s, train acc=0.89, train loss=2507.56, validation acc=0.88, validation loss=422.03
# Epoch 18: 69.09s, train acc=0.89, train loss=2407.00, validation acc=0.89, validation loss=405.29
# Epoch 19: 72.15s, train acc=0.89, train loss=2325.26, validation acc=0.89, validation loss=391.80
# Epoch 20: 75.20s, train acc=0.90, train loss=2254.68, validation acc=0.89, validation loss=380.27
# Running experiment: Optimizer=momentum, Activation=selu, Learning Rate=0.01
# Epoch 1: 3.98s, train acc=0.90, train loss=2219.78, validation acc=0.90, validation loss=375.80
# Epoch 2: 9.84s, train acc=0.91, train loss=1878.38, validation acc=0.91, validation loss=321.60
# Epoch 3: 13.68s, train acc=0.92, train loss=1707.45, validation acc=0.92, validation loss=298.00
# Epoch 4: 17.45s, train acc=0.92, train loss=1604.68, validation acc=0.92, validation loss=282.94
# Epoch 5: 23.91s, train acc=0.93, train loss=1515.56, validation acc=0.92, validation loss=270.50
# Epoch 6: 27.65s, train acc=0.93, train loss=1463.68, validation acc=0.93, validation loss=261.09
# Epoch 7: 31.51s, train acc=0.93, train loss=1381.11, validation acc=0.93, validation loss=251.30
# Epoch 8: 37.72s, train acc=0.94, train loss=1319.52, validation acc=0.93, validation loss=241.62
# Epoch 9: 41.50s, train acc=0.94, train loss=1262.19, validation acc=0.93, validation loss=233.97
# Epoch 10: 45.27s, train acc=0.94, train loss=1209.56, validation acc=0.94, validation loss=226.82
# Epoch 11: 51.23s, train acc=0.95, train loss=1152.64, validation acc=0.94, validation loss=219.14
# Epoch 12: 54.95s, train acc=0.95, train loss=1100.78, validation acc=0.94, validation loss=211.59
# Epoch 13: 58.72s, train acc=0.95, train loss=1054.12, validation acc=0.94, validation loss=204.35
# Epoch 14: 64.08s, train acc=0.95, train loss=1012.98, validation acc=0.94, validation loss=197.98
# Epoch 15: 68.42s, train acc=0.95, train loss=985.26, validation acc=0.94, validation loss=195.42
# Epoch 16: 72.14s, train acc=0.96, train loss=930.64, validation acc=0.95, validation loss=185.88
# Epoch 17: 76.14s, train acc=0.96, train loss=895.16, validation acc=0.95, validation loss=181.76
# Epoch 18: 81.81s, train acc=0.96, train loss=857.10, validation acc=0.95, validation loss=174.90
# Epoch 19: 85.59s, train acc=0.96, train loss=839.71, validation acc=0.95, validation loss=172.63
# Epoch 20: 89.33s, train acc=0.96, train loss=793.43, validation acc=0.95, validation loss=166.32
# Running experiment: Optimizer=momentum, Activation=selu, Learning Rate=0.001
# Epoch 1: 3.75s, train acc=0.79, train loss=6192.17, validation acc=0.78, validation loss=1033.96
# Epoch 2: 8.76s, train acc=0.84, train loss=4329.19, validation acc=0.83, validation loss=724.22
# Epoch 3: 13.38s, train acc=0.86, train loss=3549.46, validation acc=0.85, validation loss=595.32
# Epoch 4: 17.20s, train acc=0.87, train loss=3120.45, validation acc=0.87, validation loss=524.31
# Epoch 5: 21.36s, train acc=0.88, train loss=2847.09, validation acc=0.87, validation loss=478.91
# Epoch 6: 26.91s, train acc=0.88, train loss=2656.93, validation acc=0.88, validation loss=447.60
# Epoch 7: 30.73s, train acc=0.89, train loss=2515.90, validation acc=0.88, validation loss=424.28
# Epoch 8: 34.53s, train acc=0.89, train loss=2407.80, validation acc=0.89, validation loss=406.43
# Epoch 9: 40.65s, train acc=0.89, train loss=2321.09, validation acc=0.89, validation loss=392.30
# Epoch 10: 44.43s, train acc=0.90, train loss=2249.67, validation acc=0.89, validation loss=380.48
# Epoch 11: 48.19s, train acc=0.90, train loss=2189.77, validation acc=0.89, validation loss=370.85
# Epoch 12: 54.52s, train acc=0.90, train loss=2138.28, validation acc=0.90, validation loss=362.53
# Epoch 13: 58.28s, train acc=0.90, train loss=2093.26, validation acc=0.90, validation loss=355.18
# Epoch 14: 62.12s, train acc=0.90, train loss=2053.78, validation acc=0.90, validation loss=348.81
# Epoch 15: 68.07s, train acc=0.90, train loss=2018.30, validation acc=0.90, validation loss=343.17
# Epoch 16: 71.85s, train acc=0.91, train loss=1986.69, validation acc=0.90, validation loss=338.20
# Epoch 17: 75.62s, train acc=0.91, train loss=1958.99, validation acc=0.90, validation loss=333.89
# Epoch 18: 81.24s, train acc=0.91, train loss=1931.40, validation acc=0.90, validation loss=329.54
# Epoch 19: 85.20s, train acc=0.91, train loss=1906.93, validation acc=0.91, validation loss=325.90
# Epoch 20: 88.93s, train acc=0.91, train loss=1884.73, validation acc=0.91, validation loss=322.50
# Running experiment: Optimizer=momentum, Activation=elu, Learning Rate=0.01
# Epoch 1: 3.67s, train acc=0.88, train loss=2717.51, validation acc=0.87, validation loss=456.76
# Epoch 2: 8.28s, train acc=0.90, train loss=2132.81, validation acc=0.90, validation loss=359.88
# Epoch 3: 13.16s, train acc=0.91, train loss=1926.39, validation acc=0.91, validation loss=328.03
# Epoch 4: 17.03s, train acc=0.91, train loss=1804.12, validation acc=0.91, validation loss=309.67
# Epoch 5: 20.77s, train acc=0.92, train loss=1716.45, validation acc=0.92, validation loss=295.07
# Epoch 6: 27.00s, train acc=0.92, train loss=1643.38, validation acc=0.92, validation loss=284.60
# Epoch 7: 30.80s, train acc=0.93, train loss=1575.93, validation acc=0.92, validation loss=274.70
# Epoch 8: 34.57s, train acc=0.93, train loss=1511.06, validation acc=0.93, validation loss=266.01
# Epoch 9: 40.69s, train acc=0.93, train loss=1451.73, validation acc=0.93, validation loss=257.60
# Epoch 10: 44.44s, train acc=0.93, train loss=1399.71, validation acc=0.93, validation loss=248.81
# Epoch 11: 48.34s, train acc=0.94, train loss=1345.91, validation acc=0.93, validation loss=241.60
# Epoch 12: 54.10s, train acc=0.94, train loss=1285.93, validation acc=0.94, validation loss=232.61
# Epoch 13: 57.83s, train acc=0.94, train loss=1238.27, validation acc=0.94, validation loss=226.05
# Epoch 14: 61.58s, train acc=0.94, train loss=1188.23, validation acc=0.94, validation loss=217.48
# Epoch 15: 66.62s, train acc=0.95, train loss=1145.28, validation acc=0.94, validation loss=211.09
# Epoch 16: 71.08s, train acc=0.95, train loss=1091.14, validation acc=0.94, validation loss=203.32
# Epoch 17: 74.86s, train acc=0.95, train loss=1054.89, validation acc=0.95, validation loss=196.90
# Epoch 18: 78.88s, train acc=0.95, train loss=1012.53, validation acc=0.95, validation loss=190.83
# Epoch 19: 84.47s, train acc=0.95, train loss=979.87, validation acc=0.95, validation loss=185.62
# Epoch 20: 88.26s, train acc=0.96, train loss=941.21, validation acc=0.95, validation loss=180.93
# Running experiment: Optimizer=momentum, Activation=elu, Learning Rate=0.001
# Epoch 1: 4.02s, train acc=0.67, train loss=10245.18, validation acc=0.67, validation loss=1708.04
# Epoch 2: 7.94s, train acc=0.78, train loss=7361.89, validation acc=0.78, validation loss=1228.02
# Epoch 3: 12.71s, train acc=0.82, train loss=5552.07, validation acc=0.82, validation loss=926.58
# Epoch 4: 17.64s, train acc=0.84, train loss=4503.27, validation acc=0.84, validation loss=751.76
# Epoch 5: 21.43s, train acc=0.85, train loss=3866.45, validation acc=0.85, validation loss=645.65
# Epoch 6: 25.55s, train acc=0.86, train loss=3450.62, validation acc=0.86, validation loss=576.63
# Epoch 7: 31.21s, train acc=0.87, train loss=3162.87, validation acc=0.87, validation loss=528.99
# Epoch 8: 34.95s, train acc=0.88, train loss=2951.44, validation acc=0.87, validation loss=493.71
# Epoch 9: 38.76s, train acc=0.88, train loss=2790.97, validation acc=0.88, validation loss=467.33
# Epoch 10: 45.00s, train acc=0.88, train loss=2664.76, validation acc=0.88, validation loss=446.73
# Epoch 11: 48.69s, train acc=0.89, train loss=2562.13, validation acc=0.88, validation loss=429.89
# ...
# Epoch 4: 30.80s, train acc=0.97, train loss=723.87, validation acc=0.96, validation loss=156.53
# Epoch 5: 39.53s, train acc=0.97, train loss=733.05, validation acc=0.96, validation loss=161.74
# Epoch 6: 45.86s, train acc=0.96, train loss=756.94, validation acc=0.95, validation loss=167.86
# Epoch 7: 54.65s, train acc=0.97, train loss=709.63, validation acc=0.96, validation loss=160.39
# Epoch 8: 61.07s, train acc=0.95, train loss=989.17, validation acc=0.94, validation loss=201.48
# Epoch 9: 69.70s, train acc=0.96, train loss=886.89, validation acc=0.95, validation loss=189.23
# Epoch 10: 76.33s, train acc=0.96, train loss=842.42, validation acc=0.95, validation loss=175.67
# Epoch 11: 84.35s, train acc=0.96, train loss=823.94, validation acc=0.95, validation loss=178.27
# Epoch 12: 91.21s, train acc=0.95, train loss=1058.40, validation acc=0.94, validation loss=210.51
# Epoch 13: 98.62s, train acc=0.94, train loss=1098.15, validation acc=0.94, validation loss=225.69
# Epoch 14: 106.36s, train acc=0.94, train loss=1259.42, validation acc=0.93, validation loss=258.31
# Epoch 15: 112.91s, train acc=0.93, train loss=1498.23, validation acc=0.92, validation loss=276.18
# Epoch 16: 120.87s, train acc=0.92, train loss=1531.60, validation acc=0.92, validation loss=286.34
# Epoch 17: 127.20s, train acc=0.93, train loss=1414.37, validation acc=0.93, validation loss=263.29
# Epoch 18: 135.28s, train acc=0.89, train loss=2096.24, validation acc=0.89, validation loss=377.91
# Epoch 19: 141.60s, train acc=0.82, train loss=3458.72, validation acc=0.82, validation loss=588.43
# Epoch 20: 149.75s, train acc=0.88, train loss=2290.96, validation acc=0.87, validation loss=412.58
# Running experiment: Optimizer=adam, Activation=tanh, Learning Rate=0.001
# Epoch 1: 6.27s, train acc=0.95, train loss=1574.96, validation acc=0.94, validation loss=272.90
# Epoch 2: 15.09s, train acc=0.96, train loss=1193.29, validation acc=0.95, validation loss=214.45
# Epoch 3: 21.48s, train acc=0.97, train loss=967.94, validation acc=0.96, validation loss=180.07
# Epoch 4: 30.18s, train acc=0.97, train loss=809.09, validation acc=0.96, validation loss=156.80
# Epoch 5: 36.48s, train acc=0.98, train loss=712.60, validation acc=0.96, validation loss=143.06
# Epoch 6: 45.15s, train acc=0.98, train loss=609.44, validation acc=0.97, validation loss=128.94
# Epoch 7: 51.49s, train acc=0.98, train loss=529.16, validation acc=0.97, validation loss=118.70
# Epoch 8: 60.12s, train acc=0.98, train loss=496.21, validation acc=0.97, validation loss=116.24
# Epoch 9: 66.54s, train acc=0.99, train loss=423.83, validation acc=0.97, validation loss=105.50
# Epoch 10: 74.81s, train acc=0.99, train loss=395.49, validation acc=0.97, validation loss=101.24
# Epoch 11: 83.14s, train acc=0.99, train loss=342.47, validation acc=0.97, validation loss=95.34
# Epoch 12: 91.09s, train acc=0.99, train loss=302.00, validation acc=0.97, validation loss=89.72
# Epoch 13: 97.70s, train acc=0.99, train loss=278.45, validation acc=0.97, validation loss=87.47
# Epoch 14: 105.43s, train acc=0.99, train loss=262.72, validation acc=0.97, validation loss=88.98
# Epoch 15: 112.32s, train acc=0.99, train loss=233.02, validation acc=0.97, validation loss=83.10
# Epoch 16: 119.84s, train acc=0.99, train loss=215.48, validation acc=0.98, validation loss=81.66
# Epoch 17: 126.52s, train acc=1.00, train loss=196.98, validation acc=0.98, validation loss=81.57
# Epoch 18: 134.01s, train acc=1.00, train loss=183.62, validation acc=0.98, validation loss=82.66
# Epoch 19: 140.85s, train acc=1.00, train loss=170.58, validation acc=0.98, validation loss=78.56
# Epoch 20: 148.24s, train acc=1.00, train loss=152.27, validation acc=0.98, validation loss=76.67
# Running experiment: Optimizer=adam, Activation=leaky_relu, Learning Rate=0.01
# Epoch 1: 4.01s, train acc=0.93, train loss=1362.80, validation acc=0.93, validation loss=250.00
# Epoch 2: 10.50s, train acc=0.95, train loss=1008.56, validation acc=0.94, validation loss=203.88
# Epoch 3: 14.61s, train acc=0.95, train loss=971.34, validation acc=0.94, validation loss=199.33
# Epoch 4: 18.74s, train acc=0.94, train loss=1290.27, validation acc=0.93, validation loss=255.58
# Epoch 5: 25.45s, train acc=0.97, train loss=595.96, validation acc=0.95, validation loss=149.82
# Epoch 6: 29.60s, train acc=0.97, train loss=651.15, validation acc=0.95, validation loss=161.46
# Epoch 7: 33.75s, train acc=0.97, train loss=593.30, validation acc=0.96, validation loss=164.61
# Epoch 8: 40.26s, train acc=0.97, train loss=538.54, validation acc=0.96, validation loss=152.45
# Epoch 9: 44.41s, train acc=0.98, train loss=452.46, validation acc=0.96, validation loss=144.32
# Epoch 10: 48.43s, train acc=0.97, train loss=509.09, validation acc=0.96, validation loss=151.32
# Epoch 11: 55.08s, train acc=0.98, train loss=405.17, validation acc=0.96, validation loss=141.19
# Epoch 12: 59.20s, train acc=0.97, train loss=631.55, validation acc=0.96, validation loss=188.88
# Epoch 13: 63.52s, train acc=0.98, train loss=357.76, validation acc=0.96, validation loss=146.33
# Epoch 14: 69.58s, train acc=0.99, train loss=254.66, validation acc=0.97, validation loss=128.70
# Epoch 15: 73.67s, train acc=0.98, train loss=510.48, validation acc=0.96, validation loss=171.11
# Epoch 16: 78.12s, train acc=0.98, train loss=281.34, validation acc=0.96, validation loss=138.31
# Epoch 17: 84.15s, train acc=0.99, train loss=258.60, validation acc=0.97, validation loss=132.44
# Epoch 18: 88.22s, train acc=0.99, train loss=168.14, validation acc=0.97, validation loss=126.17
# Epoch 19: 92.71s, train acc=0.99, train loss=269.54, validation acc=0.96, validation loss=157.49
# Epoch 20: 98.53s, train acc=0.99, train loss=184.45, validation acc=0.97, validation loss=136.33
# Running experiment: Optimizer=adam, Activation=leaky_relu, Learning Rate=0.001
# Epoch 1: 4.11s, train acc=0.95, train loss=1038.68, validation acc=0.95, validation loss=189.48
# Epoch 2: 8.79s, train acc=0.96, train loss=771.03, validation acc=0.96, validation loss=151.24
# Epoch 3: 14.86s, train acc=0.97, train loss=629.77, validation acc=0.96, validation loss=134.09
# Epoch 4: 19.22s, train acc=0.98, train loss=537.40, validation acc=0.97, validation loss=124.23
# Epoch 5: 24.34s, train acc=0.98, train loss=460.65, validation acc=0.97, validation loss=113.09
# Epoch 6: 29.84s, train acc=0.98, train loss=398.13, validation acc=0.97, validation loss=107.12
# Epoch 7: 34.12s, train acc=0.98, train loss=346.48, validation acc=0.97, validation loss=100.88
# Epoch 8: 39.81s, train acc=0.99, train loss=328.10, validation acc=0.97, validation loss=101.76
# Epoch 9: 46.73s, train acc=0.99, train loss=291.27, validation acc=0.97, validation loss=98.86
# Epoch 10: 51.01s, train acc=0.99, train loss=270.49, validation acc=0.97, validation loss=96.79
# Epoch 11: 57.56s, train acc=0.99, train loss=263.50, validation acc=0.97, validation loss=101.37
# Epoch 12: 61.78s, train acc=0.99, train loss=242.45, validation acc=0.97, validation loss=96.85
# Epoch 13: 65.96s, train acc=0.99, train loss=267.78, validation acc=0.97, validation loss=108.98
# Epoch 14: 72.63s, train acc=0.99, train loss=246.18, validation acc=0.97, validation loss=107.39
# Epoch 15: 76.88s, train acc=0.99, train loss=210.34, validation acc=0.97, validation loss=100.52
# Epoch 16: 81.16s, train acc=0.99, train loss=216.87, validation acc=0.97, validation loss=107.25
# Epoch 17: 87.84s, train acc=0.99, train loss=193.02, validation acc=0.97, validation loss=107.64
# Epoch 18: 92.10s, train acc=0.99, train loss=178.70, validation acc=0.98, validation loss=102.04
# Epoch 19: 96.70s, train acc=0.99, train loss=185.97, validation acc=0.97, validation loss=117.70
# Epoch 20: 102.82s, train acc=0.99, train loss=163.68, validation acc=0.98, validation loss=104.57
# Running experiment: Optimizer=adam, Activation=selu, Learning Rate=0.01
# Epoch 1: 4.65s, train acc=0.22, train loss=26091.52, validation acc=0.21, validation loss=4327.46
# Epoch 2: 11.96s, train acc=0.21, train loss=30105.39, validation acc=0.20, validation loss=5011.54
# Epoch 3: 16.69s, train acc=0.21, train loss=32800.48, validation acc=0.20, validation loss=5465.43
# Epoch 4: 21.89s, train acc=0.22, train loss=31253.85, validation acc=0.21, validation loss=5205.07
# Epoch 5: 28.07s, train acc=0.20, train loss=30111.46, validation acc=0.19, validation loss=5002.42
# Epoch 6: 32.75s, train acc=0.12, train loss=44690.38, validation acc=0.12, validation loss=7392.29
# Epoch 7: 39.76s, train acc=0.15, train loss=42789.53, validation acc=0.15, validation loss=7067.66
# Epoch 8: 44.44s, train acc=0.18, train loss=35805.81, validation acc=0.18, validation loss=5897.58
# Epoch 9: 49.18s, train acc=0.10, train loss=120506.88, validation acc=0.10, validation loss=20269.64
# Epoch 10: 56.11s, train acc=0.10, train loss=120506.91, validation acc=0.10, validation loss=20269.64
# Epoch 11: 60.78s, train acc=0.10, train loss=120506.91, validation acc=0.10, validation loss=20269.64
# Epoch 12: 67.01s, train acc=0.10, train loss=120506.91, validation acc=0.10, validation loss=20269.64
# Epoch 13: 72.11s, train acc=0.10, train loss=120506.91, validation acc=0.10, validation loss=20269.64
# Epoch 14: 76.78s, train acc=0.10, train loss=120506.91, validation acc=0.10, validation loss=20269.64
# Epoch 15: 83.85s, train acc=0.10, train loss=120506.91, validation acc=0.10, validation loss=20269.64
# Epoch 16: 88.53s, train acc=0.10, train loss=120506.91, validation acc=0.10, validation loss=20269.64
# Epoch 17: 93.70s, train acc=0.10, train loss=120506.91, validation acc=0.10, validation loss=20269.64
# Epoch 18: 99.98s, train acc=0.10, train loss=120506.91, validation acc=0.10, validation loss=20269.64
# Epoch 19: 104.68s, train acc=0.10, train loss=120506.90, validation acc=0.10, validation loss=20269.64
# Epoch 20: 111.68s, train acc=0.10, train loss=120506.90, validation acc=0.10, validation loss=20269.64
# Running experiment: Optimizer=adam, Activation=selu, Learning Rate=0.001
# Epoch 1: 5.53s, train acc=0.94, train loss=1278.53, validation acc=0.93, validation loss=235.24
# Epoch 2: 12.01s, train acc=0.95, train loss=988.47, validation acc=0.95, validation loss=192.52
# Epoch 3: 16.88s, train acc=0.96, train loss=830.77, validation acc=0.95, validation loss=168.12
# Epoch 4: 24.34s, train acc=0.97, train loss=681.70, validation acc=0.96, validation loss=145.29
# Epoch 5: 29.13s, train acc=0.97, train loss=601.40, validation acc=0.96, validation loss=135.73
# Epoch 6: 34.99s, train acc=0.98, train loss=535.80, validation acc=0.96, validation loss=126.05
# Epoch 7: 40.81s, train acc=0.98, train loss=486.64, validation acc=0.96, validation loss=123.84
# Epoch 8: 45.62s, train acc=0.98, train loss=430.89, validation acc=0.97, validation loss=112.88
# Epoch 9: 54.70s, train acc=0.98, train loss=397.97, validation acc=0.97, validation loss=113.16
# Epoch 10: 59.55s, train acc=0.98, train loss=347.43, validation acc=0.97, validation loss=105.65
# Epoch 11: 64.68s, train acc=0.99, train loss=320.01, validation acc=0.97, validation loss=105.48
# Epoch 12: 71.23s, train acc=0.99, train loss=318.71, validation acc=0.97, validation loss=107.70
# Epoch 13: 76.08s, train acc=0.99, train loss=275.19, validation acc=0.97, validation loss=101.76
# Epoch 14: 83.20s, train acc=0.99, train loss=255.72, validation acc=0.97, validation loss=102.25
# Epoch 15: 87.98s, train acc=0.99, train loss=239.90, validation acc=0.97, validation loss=100.28
# Epoch 16: 93.25s, train acc=0.99, train loss=231.03, validation acc=0.97, validation loss=101.84
# Epoch 17: 99.85s, train acc=0.99, train loss=212.75, validation acc=0.97, validation loss=102.21
# Epoch 18: 104.64s, train acc=0.99, train loss=204.55, validation acc=0.97, validation loss=102.56
# Epoch 19: 111.63s, train acc=0.99, train loss=201.00, validation acc=0.97, validation loss=99.41
# Epoch 20: 116.51s, train acc=0.99, train loss=191.44, validation acc=0.97, validation loss=104.79
# Running experiment: Optimizer=adam, Activation=elu, Learning Rate=0.01
# Epoch 1: 4.69s, train acc=0.77, train loss=5982.38, validation acc=0.77, validation loss=1014.58
# Epoch 2: 9.74s, train acc=0.51, train loss=20680.51, validation acc=0.51, validation loss=3458.89
# Epoch 3: 16.44s, train acc=0.51, train loss=22693.93, validation acc=0.51, validation loss=3755.39
# Epoch 4: 21.25s, train acc=0.50, train loss=23582.55, validation acc=0.50, validation loss=3927.88
# Epoch 5: 28.05s, train acc=0.34, train loss=45267.39, validation acc=0.34, validation loss=7627.49
# Epoch 6: 32.79s, train acc=0.27, train loss=68001.42, validation acc=0.27, validation loss=11302.57
# Epoch 7: 37.46s, train acc=0.30, train loss=64246.03, validation acc=0.30, validation loss=10726.90
# Epoch 8: 44.66s, train acc=0.31, train loss=62154.88, validation acc=0.32, validation loss=10385.51
# Epoch 9: 49.29s, train acc=0.33, train loss=60068.50, validation acc=0.33, validation loss=10047.66
# Epoch 10: 55.39s, train acc=0.18, train loss=103379.70, validation acc=0.17, validation loss=17326.01
# Epoch 11: 60.61s, train acc=0.18, train loss=103369.66, validation acc=0.17, validation loss=17324.23
# Epoch 12: 65.23s, train acc=0.18, train loss=103352.84, validation acc=0.17, validation loss=17321.24
# Epoch 13: 72.23s, train acc=0.18, train loss=103326.92, validation acc=0.17, validation loss=17316.62
# Epoch 14: 76.89s, train acc=0.18, train loss=103287.26, validation acc=0.17, validation loss=17309.54
# Epoch 15: 81.96s, train acc=0.18, train loss=103225.57, validation acc=0.17, validation loss=17298.55
# Epoch 16: 88.20s, train acc=0.18, train loss=103122.14, validation acc=0.17, validation loss=17280.12
# Epoch 17: 92.85s, train acc=0.18, train loss=102961.31, validation acc=0.18, validation loss=17251.35
# Epoch 18: 99.70s, train acc=0.18, train loss=102743.88, validation acc=0.18, validation loss=17212.39
# Epoch 19: 104.32s, train acc=0.18, train loss=102430.54, validation acc=0.18, validation loss=17156.03
# Epoch 20: 108.92s, train acc=0.19, train loss=101963.42, validation acc=0.18, validation loss=17071.52
# Running experiment: Optimizer=adam, Activation=elu, Learning Rate=0.001
# Epoch 1: 4.74s, train acc=0.94, train loss=1128.65, validation acc=0.94, validation loss=211.21
# Epoch 2: 11.87s, train acc=0.96, train loss=840.22, validation acc=0.95, validation loss=167.35
# Epoch 3: 16.62s, train acc=0.97, train loss=678.50, validation acc=0.96, validation loss=140.79
# Epoch 4: 21.78s, train acc=0.97, train loss=548.43, validation acc=0.96, validation loss=121.76
# Epoch 5: 28.72s, train acc=0.98, train loss=474.15, validation acc=0.97, validation loss=113.67
# Epoch 6: 33.56s, train acc=0.98, train loss=412.33, validation acc=0.97, validation loss=110.17
# Epoch 7: 42.04s, train acc=0.98, train loss=344.99, validation acc=0.97, validation loss=101.74
# Epoch 8: 47.05s, train acc=0.99, train loss=296.27, validation acc=0.97, validation loss=94.98
# Epoch 9: 51.90s, train acc=0.99, train loss=253.08, validation acc=0.97, validation loss=91.81
# Epoch 10: 58.71s, train acc=0.99, train loss=227.34, validation acc=0.97, validation loss=92.16
# Epoch 11: 63.57s, train acc=0.99, train loss=205.53, validation acc=0.97, validation loss=93.52
# Epoch 12: 70.79s, train acc=0.99, train loss=177.12, validation acc=0.97, validation loss=91.43
# Epoch 13: 75.58s, train acc=0.99, train loss=157.49, validation acc=0.97, validation loss=88.77
# Epoch 14: 80.40s, train acc=0.99, train loss=137.39, validation acc=0.97, validation loss=90.58
# Epoch 15: 87.35s, train acc=1.00, train loss=127.67, validation acc=0.97, validation loss=92.31
# Epoch 16: 92.11s, train acc=1.00, train loss=117.47, validation acc=0.97, validation loss=89.47
# Epoch 17: 99.20s, train acc=1.00, train loss=107.98, validation acc=0.97, validation loss=96.12
# Epoch 18: 103.95s, train acc=1.00, train loss=92.28, validation acc=0.97, validation loss=96.29
# Epoch 19: 108.77s, train acc=1.00, train loss=87.74, validation acc=0.97, validation loss=93.44
# Epoch 20: 115.92s, train acc=1.00, train loss=63.32, validation acc=0.98, validation loss=91.86
# Best combination: Optimizer=adam, Activation=elu, Learning Rate=0.001
# Final accuracy: 0.9985333333333334

# %% [markdown]
# # MLP as function Approximator
# We know that a MLP with one hidden layer could  approximate any smooth function! <br> Here you will manually fit a sine function using ReLU activation. <br>You need to set the correct weights on ReLUs so the linear combination approximates the desired function.

# %%
import torch
import numpy as np
import matplotlib.pyplot as plt

def relu_approximation(input_data, target_labels):
    num_relus = input_data.shape[0] - 1
    x_points = torch.linspace(torch.min(input_data), torch.max(input_data), 1000)
    biases = input_data[:-1, 0]
    activation_map = torch.zeros(num_relus, len(x_points))
    for relu_idx in range(num_relus):
        activation_map[relu_idx, :] = torch.relu(x_points - biases[relu_idx])
    relu_weights = torch.zeros(num_relus)
    previous_slope = 0
    for j in range(num_relus):
        current_slope = (target_labels[j + 1] - target_labels[j]) / (input_data[j + 1] - input_data[j])
        relu_weights[j] = current_slope - previous_slope
        previous_slope = current_slope
    predicted_labels = relu_weights @ activation_map
    return predicted_labels, activation_map, x_points

def plot_function_apx(x_points, activation_map, predicted_output):
    plt.figure(figsize=(12, 6))
    for i in range(activation_map.shape[0]):
        plt.plot(x_points, activation_map[i, :].numpy(), '--', label=f'ReLU {i+1}')
    plt.plot(x_points, predicted_output.numpy(), label='Predicted Output', linewidth=2, color='red')
    plt.title('ReLU Approximation')
    plt.xlabel('x')
    plt.ylabel('y')
    plt.legend()
    plt.grid()
    plt.show()

num_samples = 10
input_data = torch.linspace(0, 2 * np.pi, num_samples).view(-1, 1)
target_labels = torch.sin(input_data)
predicted_output, activation_map, x_points = relu_approximation(input_data, target_labels)
plot_function_apx(x_points, activation_map, predicted_output)

# %% [markdown]
# # Depth vs. Width
# Here we wanna see the effect of width vs. depth on a classification task.First you are going to implement MLP again; But with 2 differences: <br>
#
# 1.   It is general purpose (i.e. works for desired depth and activation functions)
# 2.   You will implement it using pytorch

# %%
class MLP_pytorch(nn.Module):
  """
  Simulate MLP Network
  """

  def __init__(self, activation_fn, input_feature_num, hidden_unit_nums, output_feature_num):
    """
    Initialize MLP Network parameters

    Args:
      activation_fn: string
        Activation function
      input_feature_num: int
        Number of input features
      hidden_unit_nums: list
        Number of units per hidden layer. List of integers
      output_feature_num: int
        Number of output features

    Returns:
      Nothing
    """
    super(MLP_pytorch, self).__init__()
    self.input_feature_num = input_feature_num
    self.mlp = nn.Sequential()

    in_num = input_feature_num
    ##############################---TODO---##############################
    for i in range(len(hidden_unit_nums)):
        layer = nn.Linear(in_num, hidden_unit_nums[i])
        self.mlp.add_module(f'Hidden_Linear_{i+1}', layer)

        if activation_fn == 'relu':
            self.mlp.add_module(f'ReLU_{i+1}', nn.ReLU())
        elif activation_fn == 'tanh':
            self.mlp.add_module(f'Tanh_{i+1}', nn.Tanh())
        elif activation_fn == 'sigmoid':
            self.mlp.add_module(f'Sigmoid_{i+1}', nn.Sigmoid())
        else:
            raise ValueError(f"Unsupported activation function: {activation_fn}")

        in_num = hidden_unit_nums[i]

    out_layer = nn.Linear(in_num, output_feature_num)
    self.mlp.add_module('Output_Linear', out_layer)

    ##############################---TODO---##############################

  def forward(self, x):
    """
    Simulate forward pass of MLP Network

    Args:
      x: torch.tensor
        Input data

    Returns:
      logits: Instance of MLP
        Forward pass of MLP
    """
    x = x.view(-1, self.input_feature_num)
    logits = self.mlp(x)

    return logits

# %% [markdown]
# Now let's make a spiral dataset that follows this formula:
# \begin{equation}
# \begin{array}{c}
# X_{k}(t)=t\left(\begin{array}{c}
# \sin \left[\frac{2 \pi}{K}\left(2 t+k-1\right)\right]+\mathcal{N}\left(0, \sigma\right) \\
# \cos \left[\frac{2 \pi}{K}\left(2 t+k-1\right)\right]+\mathcal{N}\left(0, \sigma\right)
# \end{array}\right)
# \end{array}, \quad 0 \leq t \leq 1, \quad k=1, \ldots, K
# \end{equation}
#
# Run cell below to create the data and load it as tensors.

# %%
# @title Data Loader
K = 4
sigma = 0.4
N = 1000
t = torch.linspace(0, 1, N)
X = torch.zeros(K*N, 2)
y = torch.zeros(K*N)
for k in range(K):
  X[k*N:(k+1)*N, 0] = t*(torch.sin(2*np.pi/K*(2*t+k)) + sigma**2*torch.randn(N))
  X[k*N:(k+1)*N, 1] = t*(torch.cos(2*np.pi/K*(2*t+k)) + sigma**2*torch.randn(N))
  y[k*N:(k+1)*N] = k


X_test, y_test, X_train, y_train = shuffle_and_split_data(X, y, seed=SEED)

# DataLoader with random seed
batch_size = 128
g_seed = torch.Generator()
g_seed.manual_seed(SEED)

test_data = TensorDataset(X_test, y_test)
test_loader = DataLoader(test_data, batch_size=batch_size,
                         shuffle=False, num_workers=0,
                         worker_init_fn=seed_worker,
                         generator=g_seed,
                         )

train_data = TensorDataset(X_train, y_train)
train_loader = DataLoader(train_data,
                          batch_size=batch_size,
                          drop_last=True,
                          shuffle=True,
                          worker_init_fn=seed_worker,
                          generator=g_seed,
                          )

# %% [markdown]
# Now we will add more polynomial features to the dataset to make the first layer wider. Afterwards, train a single linear layer. We could use the same MLP network with no hidden layers (though it would not be called an MLP anymore!).
#
# Add polynomial terms up to $P=50$ which means that for every $x_1^n x_2^m$ term, $n+m\leq P$. Total number of polynomial features up to $P$ follows this formula:
#
# \begin{equation}
# \text{# of terms} = \frac{(P+1)(P+2)}{2}
# \end{equation}
#
# Also, we don't need the polynomial term with degree zero (which is the constatnt term) since `nn.Linear` layers have bias terms. Therefore we will have one fewer polynomial feature.

# %%
def polynomial_classifier(poly_degree, seed=0):
  """
  Helper function to run the polynomial classifier

  Args:
    poly_degree: int
      Degree of the polynomial
    seed: int
      A non-negative integer that defines the random state.

  Returns:
    num_features: int
      Number of features
  """

  def polynomial_features(poly_degree, X):
    """
    Function to define the number of polynomial features except the bias term

    Args:
      poly_degree: int
        Degree of the polynomial
      X: torch.tensor
        Input data

    Returns:
      num_features: int
        Number of features
      poly_X: torch.tensor
        Polynomial term
    """
    ##############################---TODO---##############################
    num_samples = X.shape[0]
    num_features = poly_degree
    poly_X = torch.zeros(num_samples, num_features)

    for degree in range(1, poly_degree + 1):
        poly_X[:, degree - 1] = X[:, 0] ** degree

    return poly_X, num_features
    ##############################---TODO---##############################

  poly_X_test, num_features = polynomial_features(poly_degree, X_test)
  poly_X_train, _ = polynomial_features(poly_degree, X_train)

  batch_size = 128

  g_seed = torch.Generator()
  g_seed.manual_seed(seed)
  poly_test_data = TensorDataset(poly_X_test, y_test)
  poly_test_loader = DataLoader(poly_test_data,
                                batch_size=batch_size,
                                shuffle=False,
                                num_workers=1,
                                worker_init_fn=seed_worker,
                                generator=g_seed)

  poly_train_data = TensorDataset(poly_X_train, y_train)
  poly_train_loader = DataLoader(poly_train_data,
                                 batch_size=batch_size,
                                 shuffle=True,
                                 num_workers=1,
                                 worker_init_fn=seed_worker,
                                 generator=g_seed)

  poly_net = MLP_pytorch('ReLU()', num_features, [], K)


  criterion = nn.CrossEntropyLoss()
  optimizer = optim.Adam(poly_net.parameters(), lr=1e-3)
  _, _ = train_test_classification(poly_net, criterion, optimizer,
                                   poly_train_loader, poly_test_loader,
                                   num_epochs=100)
  X_all = sample_grid()
  poly_X_all, _ = polynomial_features(poly_degree, X_all)
  y_pred = poly_net(poly_X_all)

  # Plot
  plot_decision_map(X_all.cpu(), y_pred.cpu(), X_test.cpu(), y_test.cpu())
  plt.show()

  return num_features

# %% [markdown]
# ### Train the network. How does it generalize?

# %%
seed_setter(seed=SEED)
max_poly_deg = 50
num_features = polynomial_classifier(max_poly_deg)
print(f'Number of features: {num_features}')
# Out:
# Random seed 2024 has been set.
#   0%|          | 0/100 [00:00<?, ?it/s]
# Accuracy on the 3200 training samples: 48.72
# Accuracy on the 800 testing samples: 48.38
# Number of features: 50

# %% [markdown]
# Now create another instance of `MLP_pytorch` class having a hidden layer of 128 neurons and train it. Compare the result with the wide network. How does deeper model generalize? Is the decision boundaries ideal? Why?
# A deeper model with 128 neurons often generalizes better, learning more complex patterns and nuanced decision boundaries, but it risks overfitting compared to a wider network.

# %%
##############################---TODO---##############################
seed_setter(SEED)
net2 = MLP_pytorch(
    activation_fn='relu',
    input_feature_num=2,
    hidden_unit_nums=[32, 16],
    output_feature_num=len(torch.unique(y_train))
    )
criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(net2.parameters(), lr=1e-3)
num_epochs = 100

train_test_classification(
    net2,
    criterion,
    optimizer,
    train_loader,
    test_loader,
    num_epochs=num_epochs,
    training_plot=True
)


X_all = sample_grid()
y_pred = net2(X_all).cpu()
plot_decision_map(X_all, y_pred, X_test, y_test)

##############################---TODO---##############################
# Out:
# Random seed 2024 has been set.
#   0%|          | 0/100 [00:00<?, ?it/s]
# Accuracy on the 3200 training samples: 98.50
# Accuracy on the 800 testing samples: 98.25
